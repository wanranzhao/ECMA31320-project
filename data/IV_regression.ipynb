# %%
import pandas as pd
import numpy as np
from linearmodels import IV2SLS
from linearmodels.panel import PanelOLS, PooledOLS
from linearmodels.panel import compare

# %% [markdown]
# No fixed affects, No stationary contrls, Transport IV

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS','decade','logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Define the dependent variable
dependent = data['onset2COWCS']

# Define the endogenous variable, exogenous controls, and instrument variable
endog = data['s6']
exog = data[['decade','logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']]
instr = data['s19']

# Create the regression formula
formula = 'onset2COWCS ~ 1 + [s6 ~ s19] + decade + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff'

# Run the 2SLS regression
model_iv = IV2SLS.from_formula(formula, data)
results_iv = model_iv.fit(cov_type='clustered', clusters=data.index.get_level_values('country'))

# Print the results
print(results_iv)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            onset2COWCS   R-squared:                      0.0148
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0112
# No. Observations:                1929   F-statistic:                    13.790
# Date:                Tue, May 09 2023   P-value (F-stat)                0.0551
# Time:                        17:12:11   Distribution:                  chi2(7)
# Cov. Estimator:             clustered
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             0.0970     0.0359     2.7049     0.0068      0.0267      0.1673
# decade               -0.0112     0.0046    -2.4304     0.0151     -0.0203     -0.0022
# democracy_diff       -0.0026     0.0020    -1.3233     0.1857     -0.0065      0.0013
# ecgrowth_demeaned    -0.1977     0.0951    -2.0802     0.0375     -0.3841     -0.0114
# logoutreg_diff       -0.0629     0.3683    -0.1709     0.8643     -0.7847      0.6589
# logpop_M_diff     -2.017e+04  1.255e+05    -0.1607     0.8723  -2.662e+05   2.259e+05
# logpopdens_diff    2.018e+04  1.255e+05     0.1608     0.8723  -2.259e+05   2.662e+05
# s6                    0.1121     0.1073     1.0450     0.2960     -0.0982      0.3224
# =====================================================================================
#
# Endogenous: s6
# Instruments: s19
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 146

# %% [markdown]
# No fixed affects, No stationary controls, Fuel IV

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS','decade','logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Define the dependent variable
dependent = data['onset2COWCS']

# Define the endogenous variable, exogenous controls, and instrument variable
endog = data['s6']
exog = data[['decade','logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']]
instr = data['avgs6']

# Create the regression formula
formula = 'onset2COWCS ~ 1 + [s6 ~ avgs6] + decade + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff'

# Run the 2SLS regression
model_iv = IV2SLS.from_formula(formula, data)
results_iv = model_iv.fit(cov_type='clustered', clusters=data.index.get_level_values('country'))

# Print the results
print(results_iv)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            onset2COWCS   R-squared:                     -0.0691
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.0729
# No. Observations:                1929   F-statistic:                    12.231
# Date:                Tue, May 09 2023   P-value (F-stat)                0.0932
# Time:                        17:14:45   Distribution:                  chi2(7)
# Cov. Estimator:             clustered
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             0.0764     0.0367     2.0790     0.0376      0.0044      0.1484
# decade               -0.0078     0.0050    -1.5652     0.1175     -0.0175      0.0020
# democracy_diff       -0.0026     0.0021    -1.2408     0.2147     -0.0066      0.0015
# ecgrowth_demeaned    -0.2514     0.1094    -2.2969     0.0216     -0.4659     -0.0369
# logoutreg_diff        0.1367     0.3720     0.3676     0.7132     -0.5923      0.8658
# logpop_M_diff     -2.646e+05  3.266e+05    -0.8100     0.4180  -9.047e+05   3.756e+05
# logpopdens_diff    2.646e+05  3.266e+05     0.8100     0.4180  -3.756e+05   9.047e+05
# s6                   -1.2507     1.0796    -1.1585     0.2467     -3.3667      0.8653
# =====================================================================================
#
# Endogenous: s6
# Instruments: avgs6
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 146

# %% [markdown]
# NO Fixed effects, YES stationary controls, Transport IV

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS','decade',
                         'logmountain', 'ethnic_fractionalization',
                         'religion_fractionalization', 'language_fractionalization',
                         'leg_british', 'opec',
                         'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Define the dependent variable
dependent = data['onset2COWCS']

# Define the endogenous variable, exogenous controls, and instrument variable
endog = data['s6']
exog = data[['decade',
                'logmountain', 'ethnic_fractionalization',
                'religion_fractionalization', 'language_fractionalization',
                'leg_british', 'opec',
                'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']]
instr = data['s19']

# Create the regression formula
formula = 'onset2COWCS ~ 1 + [s6 ~ s19] + decade + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff + logmountain + ethnic_fractionalization + religion_fractionalization + language_fractionalization + leg_british + opec'

# Run the 2SLS regression
model_iv = IV2SLS.from_formula(formula, data)
results_iv = model_iv.fit(cov_type='clustered', clusters=data.index.get_level_values('country'))

# Print the results
print(results_iv)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            onset2COWCS   R-squared:                      0.0365
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.0285
# No. Observations:                1585   F-statistic:                    19.961
# Date:                Tue, May 09 2023   P-value (F-stat)                0.0962
# Time:                        17:04:22   Distribution:                 chi2(13)
# Cov. Estimator:             clustered
#
#                                      Parameter Estimates
# ==============================================================================================
#                             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1135     0.0417     2.7190     0.0065      0.0317      0.1953
# decade                        -0.0144     0.0054    -2.6635     0.0077     -0.0249     -0.0038
# democracy_diff                -0.0028     0.0022    -1.2846     0.1989     -0.0071      0.0015
# ecgrowth_demeaned             -0.3506     0.1417    -2.4738     0.0134     -0.6284     -0.0728
# ethnic_fractionalization       0.4572     1.7776     0.2572     0.7970     -3.0269      3.9413
# language_fractionalization     2.4014     1.4348     1.6737     0.0942     -0.4108      5.2135
# leg_british                    0.5236     0.9107     0.5749     0.5653     -1.2613      2.3085
# logmountain                    0.1690     0.0515     3.2843     0.0010      0.0681      0.2698
# logoutreg_diff                -0.1125     0.4709    -0.2389     0.8112     -1.0353      0.8104
# logpop_M_diff               3.084e+04  1.483e+05     0.2080     0.8352  -2.597e+05   3.214e+05
# logpopdens_diff            -3.085e+04  1.483e+05    -0.2081     0.8352  -3.214e+05   2.597e+05
# opec                           0.0024     0.0143     0.1645     0.8693     -0.0257      0.0304
# religion_fractionalization    -0.5653     1.4770    -0.3828     0.7019     -3.4602      2.3295
# s6                             0.2767     0.2093     1.3221     0.1861     -0.1335      0.6868
# ==============================================================================================
#
# Endogenous: s6
# Instruments: s19
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 120

# %% [markdown]
# NO Fixed effect, YES stationary controls, FUEL IV

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS','decade',
                         'logmountain', 'ethnic_fractionalization',
                         'religion_fractionalization', 'language_fractionalization',
                         'leg_british', 'opec',
                         'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Define the dependent variable
dependent = data['onset2COWCS']

# Define the endogenous variable, exogenous controls, and instrument variable
endog = data['s6']
exog = data[['decade',
                'logmountain', 'ethnic_fractionalization',
                'religion_fractionalization', 'language_fractionalization',
                'leg_british', 'opec',
                'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']]
instr = data['avgs6']

# Create the regression formula
formula = 'onset2COWCS ~ 1 + [s6 ~ avgs6] + decade + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff + logmountain + ethnic_fractionalization + religion_fractionalization + language_fractionalization + leg_british + opec'

# Run the 2SLS regression
model_iv = IV2SLS.from_formula(formula, data)
results_iv = model_iv.fit(cov_type='clustered', clusters=data.index.get_level_values('country'))

# Print the results
print(results_iv)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            onset2COWCS   R-squared:                     -0.0857
# Estimator:                    IV-2SLS   Adj. R-squared:                -0.0947
# No. Observations:                1585   F-statistic:                    17.364
# Date:                Tue, May 09 2023   P-value (F-stat)                0.1832
# Time:                        17:20:36   Distribution:                 chi2(13)
# Cov. Estimator:             clustered
#
#                                      Parameter Estimates
# ==============================================================================================
#                             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ----------------------------------------------------------------------------------------------
# Intercept                      0.0945     0.0425     2.2257     0.0260      0.0113      0.1778
# decade                        -0.0108     0.0055    -1.9643     0.0495     -0.0215  -2.364e-05
# democracy_diff                -0.0028     0.0023    -1.2009     0.2298     -0.0073      0.0018
# ecgrowth_demeaned             -0.4079     0.1644    -2.4810     0.0131     -0.7301     -0.0857
# ethnic_fractionalization       0.7602     1.8218     0.4173     0.6765     -2.8104      4.3309
# language_fractionalization     2.4939     1.4194     1.7570     0.0789     -0.2880      5.2757
# leg_british                    0.3155     0.9470     0.3331     0.7391     -1.5406      2.1715
# logmountain                    0.1368     0.0523     2.6152     0.0089      0.0343      0.2393
# logoutreg_diff                -0.0087     0.4875    -0.0179     0.9857     -0.9642      0.9467
# logpop_M_diff              -4.074e+05  4.881e+05    -0.8345     0.4040  -1.364e+06   5.494e+05
# logpopdens_diff             4.073e+05  4.881e+05     0.8345     0.4040  -5.494e+05   1.364e+06
# opec                           0.0012     0.0145     0.0852     0.9321     -0.0271      0.0296
# religion_fractionalization    -0.7084     1.4794    -0.4789     0.6320     -3.6079      2.1910
# s6                            -1.8195     1.3629    -1.3350     0.1819     -4.4908      0.8518
# ==============================================================================================
#
# Endogenous: s6
# Instruments: avgs6
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 120

# %% [markdown]
# YES Fixed effects, NO stationary controls, Tranport IV

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS', 's6', 's19', 'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Create country and year dummies for fixed effects
country_dummies = pd.get_dummies(data.index.get_level_values('country'), drop_first=True, prefix='C').astype(str)
year_dummies = pd.get_dummies(data.index.get_level_values('t'), drop_first=True, prefix='Y').astype(str)
dummies = pd.concat([country_dummies, year_dummies], axis=1)

# Reset index for data and concatenate with dummies
data = data.reset_index()
data_with_dummies = pd.concat([data, dummies], axis=1)

# Store the original index for later use
original_index = data_with_dummies.set_index(['country', 't']).index

# Create the regression formula including the dummies
fixed_effects = ' + '.join(dummies.columns)
formula = f'onset2COWCS ~ 1 + [s6 ~ s19] + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff + {fixed_effects}'

# Run the 2SLS regression with country and time fixed effects
model_iv = IV2SLS.from_formula(formula, data_with_dummies)
results_iv = model_iv.fit(cov_type='clustered', clusters=original_index.get_level_values('country'))

# Print the results
print(results_iv)
# Out:
#                           IV-2SLS Estimation Summary
# ==============================================================================
# Dep. Variable:            onset2COWCS   R-squared:                      0.1847
# Estimator:                    IV-2SLS   Adj. R-squared:                 0.1083
# No. Observations:                1929   F-statistic:                  2.59e+18
# Date:                Tue, May 09 2023   P-value (F-stat)                0.0000
# Time:                        18:03:27   Distribution:                chi2(165)
# Cov. Estimator:             clustered
#
#                                  Parameter Estimates
# =====================================================================================
#                    Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------
# Intercept             0.1746     0.0216     8.0860     0.0000      0.1323      0.2170
# C_ALB[T.True]        -0.1477     0.0080    -18.516     0.0000     -0.1633     -0.1320
# C_ARE[T.True]        -0.1403     0.0058    -24.004     0.0000     -0.1518     -0.1289
# C_ARG[T.True]        -0.1437     0.0066    -21.657     0.0000     -0.1567     -0.1307
# C_ARM[T.True]        -0.1528     0.0106    -14.411     0.0000     -0.1736     -0.1320
# C_AUS[T.True]        -0.1446     0.0072    -20.120     0.0000     -0.1587     -0.1305
# C_AUT[T.True]        -0.1520     0.0096    -15.847     0.0000     -0.1708     -0.1332
# C_AZE[T.True]        -0.0575     0.0057    -10.121     0.0000     -0.0686     -0.0464
# C_PRY[T.True]        -0.1496     0.0084    -17.763     0.0000     -0.1661     -0.1331
# C_RUS[T.True]         0.2372     0.0136     17.393     0.0000      0.2105      0.2639
# C_RWA[T.True]         0.0544     0.0017     31.856     0.0000      0.0511      0.0578
# C_SAU[T.True]        -0.1651     0.0205    -8.0513     0.0000     -0.2052     -0.1249
# C_SEN[T.True]        -0.1414     0.0058    -24.303     0.0000     -0.1528     -0.1300
# C_SGP[T.True]        -0.1480     0.0078    -18.898     0.0000     -0.1633     -0.1326
# C_SLE[T.True]         0.1073     0.0067     15.998     0.0000      0.0942      0.1205
# C_SLV[T.True]        -0.1445     0.0069    -20.803     0.0000     -0.1581     -0.1309
# C_SOM[T.True]        -0.1409     0.0070    -20.204     0.0000     -0.1545     -0.1272
# C_STP[T.True]        -0.1847     0.0234    -7.9028     0.0000     -0.2305     -0.1389
# C_SVK[T.True]        -0.1436     0.0072    -19.995     0.0000     -0.1577     -0.1296
# C_SVN[T.True]        -0.1479     0.0087    -17.024     0.0000     -0.1649     -0.1309
# C_SWE[T.True]        -0.1496     0.0087    -17.180     0.0000     -0.1667     -0.1325
# C_SWZ[T.True]        -0.1496     0.0087    -17.209     0.0000     -0.1667     -0.1326
# C_SYC[T.True]        -0.1766     0.0221    -7.9923     0.0000     -0.2199     -0.1333
# C_SYR[T.True]        -0.1447     0.0072    -19.971     0.0000     -0.1589     -0.1305
# C_TCD[T.True]        -0.1373     0.0040    -34.211     0.0000     -0.1451     -0.1294
# C_TGO[T.True]        -0.1503     0.0086    -17.375     0.0000     -0.1672     -0.1333
# C_THA[T.True]        -0.1497     0.0086    -17.352     0.0000     -0.1666     -0.1328
# C_TJK[T.True]        -0.0378     0.0053    -7.0737     0.0000     -0.0483     -0.0273
# C_TKM[T.True]        -0.1520     0.0093    -16.257     0.0000     -0.1703     -0.1337
# C_TTO[T.True]        -0.1417     0.0070    -20.216     0.0000     -0.1555     -0.1280
# C_TUN[T.True]        -0.1472     0.0076    -19.424     0.0000     -0.1621     -0.1324
# C_TUR[T.True]        -0.0368     0.0089    -4.1393     0.0000     -0.0542     -0.0194
# C_TWN[T.True]        -0.1472     0.0078    -18.949     0.0000     -0.1624     -0.1319
# C_TZA[T.True]        -0.1459     0.0070    -20.929     0.0000     -0.1595     -0.1322
# C_UGA[T.True]        -0.0002     0.0063    -0.0325     0.9740     -0.0125      0.0121
# C_UKR[T.True]        -0.1540     0.0106    -14.503     0.0000     -0.1748     -0.1332
# C_URY[T.True]        -0.1478     0.0080    -18.575     0.0000     -0.1634     -0.1322
# C_USA[T.True]        -0.0818     0.0080    -10.224     0.0000     -0.0974     -0.0661
# C_UZB[T.True]        -0.1498     0.0087    -17.277     0.0000     -0.1668     -0.1328
# C_VEN[T.True]        -0.1458     0.0081    -18.031     0.0000     -0.1616     -0.1299
# C_VNM[T.True]        -0.1363     0.0043    -32.046     0.0000     -0.1447     -0.1280
# C_YEM[T.True]        -0.0724     0.0069    -10.570     0.0000     -0.0859     -0.0590
# C_ZAF[T.True]        -0.1435     0.0069    -20.781     0.0000     -0.1570     -0.1300
# C_ZMB[T.True]        -0.1491     0.0082    -18.111     0.0000     -0.1653     -0.1330
# C_ZWE[T.True]        -0.1540     0.0102    -15.094     0.0000     -0.1740     -0.1340
# Y_1992[T.True]       -0.0197     0.0247    -0.7951     0.4266     -0.0681      0.0288
# Y_1993[T.True]       -0.0237     0.0218    -1.0872     0.2769     -0.0665      0.0190
# Y_1994[T.True]       -0.0191     0.0212    -0.9016     0.3672     -0.0608      0.0225
# Y_1995[T.True]       -0.0324     0.0201    -1.6081     0.1078     -0.0719      0.0071
# Y_1996[T.True]       -0.0143     0.0234    -0.6088     0.5426     -0.0602      0.0317
# Y_1997[T.True]       -0.0345     0.0216    -1.5999     0.1096     -0.0767      0.0078
# Y_1998[T.True]       -0.0056     0.0215    -0.2600     0.7949     -0.0478      0.0366
# Y_1999[T.True]       -0.0314     0.0212    -1.4808     0.1387     -0.0729      0.0102
# Y_2000[T.True]       -0.0304     0.0191    -1.5916     0.1115     -0.0679      0.0070
# Y_2001[T.True]       -0.0237     0.0227    -1.0452     0.2959     -0.0681      0.0207
# Y_2002[T.True]       -0.0418     0.0198    -2.1083     0.0350     -0.0807     -0.0029
# Y_2003[T.True]       -0.0372     0.0224    -1.6605     0.0968     -0.0811      0.0067
# Y_2004[T.True]       -0.0304     0.0221    -1.3775     0.1684     -0.0737      0.0129
# Y_2005[T.True]       -0.0418     0.0216    -1.9327     0.0533     -0.0842      0.0006
# democracy_diff       -0.0033     0.0021    -1.5968     0.1103     -0.0073      0.0007
# ecgrowth_demeaned    -0.2523     0.1011    -2.4954     0.0126     -0.4504     -0.0541
# logoutreg_diff       -0.0573     0.5544    -0.1034     0.9176     -1.1440      1.0293
# logpop_M_diff     -1.275e+04  1.256e+05    -0.1015     0.9192  -2.589e+05   2.334e+05
# logpopdens_diff    1.274e+04  1.256e+05     0.1014     0.9192  -2.334e+05   2.589e+05
# s6                    0.1329     0.1145     1.1607     0.2457     -0.0915      0.3573
# =====================================================================================
#
# Endogenous: s6
# Instruments: s19
# Clustered Covariance (One-Way)
# Debiased: False
# Num Clusters: 146

# %%
# Load the data
data = pd.read_csv('gvcomix_transformed.csv')

# Set the MultiIndex
data = data.set_index(['country', 't'])

# Drop rows with missing values in any of the columns used in the regression
columns_to_check = ['onset2COWCS', 's6', 's19', 'logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']
data = data.dropna(subset=columns_to_check)

# Create country and year dummies for fixed effects
country_dummies = pd.get_dummies(data.index.get_level_values('country'), drop_first=True, prefix='C').astype(str)
year_dummies = pd.get_dummies(data.index.get_level_values('t'), drop_first=True, prefix='Y').astype(str)
dummies = pd.concat([country_dummies, year_dummies], axis=1)

# Reset index for data and concatenate with dummies
data = data.reset_index()
data_with_dummies = pd.concat([data, dummies], axis=1)

# Store the original index for later use
original_index = data_with_dummies.set_index(['country', 't']).index

# Create the regression formula including the dummies
fixed_effects = ' + '.join(dummies.columns)
formula = f'onset2COWCS ~ 1 + [s6 ~ s19] + logpop_M_diff + logpopdens_diff + logoutreg_diff + ecgrowth_demeaned + democracy_diff + {fixed_effects}'

# Run the 2SLS regression with country and time fixed effects
model_iv = IV2SLS.from_formula(formula, data_with_dummies)
results_iv = model_iv.fit(cov_type='clustered', clusters=original_index.get_level_values('country'))

# Print the results
print(results_iv)
