# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv('eora_merged.csv')

# %%
df.columns
# Out:
# Index(['country', 'sect', 't', 'source', 'outp', 'outpd', 'outptt', 'gvco',
#        'gvcobp', 'gvcofp', 'gvcomix', 'outpd%', 'outptt%', 'gvco%', 'gvcobp%',
#        'gvcofp%', 'gvcomix%', 'outpd_diff', 'outptt_diff', 'gvco_diff',
#        'gvcobp_diff', 'gvcofp_diff', 'gvcomix_diff', 'Unnamed: 0',
#        'onset2COWCS', 'd2incidenceU', 'd3_6incidenceU', 'onsetUCS', 'coup',
#        'periregular', 'milexp_pergdpSIPRI', 'decade', 'ecgrowth', 'logpop_M',
#        'logpopdens', 'logoutreg', 'democracy', 'logmountain',
#        'ethnic_fractionalization', 'religion_fractionalization',
#        'language_fractionalization', 'leg_british', 'opec',
#        'milexp_pergdpSIPRI_diff', 'logpop_M_diff', 'logpopdens_diff',
#        'logoutreg_diff', 'ecgrowth_demeaned'],
#       dtype='object')

# %%
outcome_lst = ['onset2COWCS', 'd2incidenceU', 'd3_6incidenceU', 'onsetUCS', 'coup', 'periregular', 'milexp_pergdpSIPRI','milexp_pergdpSIPRI_diff']

# %% [markdown]
# In order to compare the variation of variables with different scales, you can use the coefficient of variation (CV). The coefficient of variation is a dimensionless measure of relative variability that is calculated by dividing the standard deviation (SD) of a variable by its mean (µ):
#
# CV = (SD / µ) * 100
#
# By calculating the CV for each variable, you can compare their relative variation and choose the one with the highest CV as the variable with the most variation.

# %%
def compute_cv(variable):
    # Convert the input list to a numpy array
    variable_array = np.array(variable)

    # Remove NaN values
    variable_array = variable_array[~np.isnan(variable_array)]

    # Calculate mean, standard deviation, and CV
    mean = np.mean(variable_array)
    std_dev = np.std(variable_array)
    cv = (std_dev / mean) * 100

    return cv

# %%
for outcome in outcome_lst:
    print(outcome, str(compute_cv(df[outcome])))
# Out:
# onset2COWCS 884.3408978043547
# d2incidenceU -6444.222218390672
# d3_6incidenceU 684.1748592978538
# onsetUCS 565.5882865566699
# coup 481.7684412920078
# periregular nan
# milexp_pergdpSIPRI 148.2030762133348
# milexp_pergdpSIPRI_diff -6209.470487463732
# C:\Users\xz\AppData\Roaming\Python\Python37\site-packages\numpy\core\fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\xz\AppData\Roaming\Python\Python37\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\xz\AppData\Roaming\Python\Python37\site-packages\numpy\core\_methods.py:263: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims, where=where)
# C:\Users\xz\AppData\Roaming\Python\Python37\site-packages\numpy\core\_methods.py:223: RuntimeWarning: invalid value encountered in true_divide
#   subok=False)
# ...

# %%
# Plot histograms for each column
for column in outcome_lst:
    arr = df[column]
    arr = arr[~np.isnan(arr)]
    plt.figure()
    plt.hist(arr, bins=10, edgecolor='black', alpha=0.7)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Below are the controls we used for our analysis

# %% [markdown]
# 'decade',
# 'ecgrowth', 'ecgrowth_demeaned'
# 'logpop_M', 'logpop_M_diff',
# 'logpopdens', 'logpopdens_diff'
# 'logoutreg', 'logoutreg_diff'
# 'democracy',
# 'logmountain',
# 'ethnic_fractionalization',
# 'religion_fractionalization',
# 'language_fractionalization',
# 'leg_british',
# 'opec'

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('merged_052423.csv')

# Count the number of distinct countries
num_countries = df['country'].nunique()

print(f"There are {num_countries} distinct countries in the CSV file.")
# Out:
# There are 181 distinct countries in the CSV file.
