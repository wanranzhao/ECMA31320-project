# %%
import pandas as pd
import numpy as np
from pydynpd import regression
import pathlib
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
import sys

# %% [markdown]
# # Questions
# 1. Should we add stationary controls?
# We do not introduce stationary controls under most circumstance.
# Usually they do not change the results a lot, but that should be verified in the robustness check.
#
# # Assumption tests
# ## AR
# We expect to reject AR(1) but not AR(2).
# ## Overidentification
# A rule of thumb is that any p-value between 0.1 and 0.25 should be fine as it is reasonably larger than a significance level of 0.05 and it is reasonably small enough to not suspect severe p-value inflation.

# %%
unstationary = 'ecgrowth_demeaned logpop_M_diff logpopdens_diff logoutreg_diff democracy_diff'
stationary = 'logmountain ethnic_fractionalization religion_fractionalization language_fractionalization leg_british opec'

columns_to_check = ['onset2COWCS','decade','logpop_M_diff', 'logpopdens_diff', 'logoutreg_diff', 'ecgrowth_demeaned', 'democracy_diff']

path = pathlib.Path().resolve()
# iv = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/transportIV_file.csv", na_values= '#DIV/0!')

# %%
path
# Out:
# PosixPath('/Users/zwanran/Desktop/ECMA31320/final/ECMA31320-project/code/Internal_IV')

# %%
def load_data(predictor = "gvcomix"):
    df = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/" + predictor + "_data.csv", na_values= '#DIV/0!')
    # df = pd.merge(df, iv, on=["country", "t"])
    
    df[columns_to_check] = df[columns_to_check].replace([np.inf, -np.inf], np.nan)
    df = df.dropna(subset=columns_to_check)
    
    label = le.fit_transform(df['country'])
    df.drop('country', axis=1, inplace=True)
    df['country'] = label
    
    # df = df.set_index(['country', 't'])
    
    # df.fillna(0, inplace=True)
    return df

# %%
def reg(method=" ", additional_cntrl = False, time = False, iv = 'trans_outp_p'):
    # System GMM by default (method = "nolevel" produces difference GMM)
    # No stationary controls by default
    # IV = transport by default
    command_str = 'onset2COWCS L(1:?).onset2COWCS s' + sector + ' ' + iv + ' ' + unstationary + ' '
    if additional_cntrl:
        command_str = command_str + stationary
    command_str = command_str + ' | gmm(onset2COWCS, 2:3) gmm(s' + sector + ', 2:3) iv(' + iv + ') | ' + ' ' + method
    if time:
         command_str = command_str + ' timedumm'
    mydpd = regression.abond(command_str, df, ['country', 't']);
    return mydpd #.models[0] #.regression_table

# %%
def all_reg():
    # world average gvc participation IV.
    # # No time FE if we are using world-level average gvc participation as external IV
    ## System GMM
    m1 = reg(iv = 'avgs' + sector);
    ## Difference GMM
    m2 = reg(iv = 'avgs' + sector, method="nolevel");

    # Transport IV
    ## System GMM
    m3 = reg();
    m4 = reg(time = True);
    ## Difference GMM
    m5 = reg(method = "nolevel");
    m6 = reg(time = True, method="nolevel");

    results = [m1, m2, m3, m4, m5, m6]
    return results

# %%
def print_results(results):
    for s in range(len(results)): # traverse through four sectors
        if s == 0:
            print("******sector 1********")
        if s == 1:
            print("******sector 2********")
        if s == 2:
            print("******sector 6********")
        if s == 4:
            print("******sector 10*******")
        for idx in range(len(results[s])):
            if idx == 0:
                print("IV = World Average; Sys.")
            if idx == 1:
                print("IV = World Average; Dif.")
            if idx == 3:
                print("IV = Transport; Sys.")
            if idx == 4:
                print("IV = World Average; Sys; t-FE.")
            if idx == 5:
                print("IV = Transport; Dif.")
            if idx == 6:
                print("IV = World Average; Dif; t-FE.")
            m = results[idx].models[0]
            print(m.regression_table)
            print("AR(1) test P value: ", end=" ")
            print(m.AR_list[0].P_value)
            print("AR(2) test P value: ", end=" ")
            print(m.AR_list[1].P_value)
            print("Hansen test P value: ", end=" ")
            print(m.hansen.p_value)
            print("\n")

# %%
predictor_list = ["gvcomix", "gvcobp", "gvcofp"]
sector_list = ['1', '2', '6', '10']
results_list = []
for predictor in predictor_list:
    df = load_data(predictor);
    predictor_result = [] ## results for every predictor
                            ## in the order of s1, s2, s6, s10
    for sector in sector_list:
        predictor_result.append(all_reg());
    results_list.append(predictor_result)
# Out:
#  m1
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 1646
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 83                       Max obs per group: 13
#  Number of groups = 142                           Avg obs per group: 11.59
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0203546  |      0.0317503      | 0.6410837  | 0.5214683 |   |
# |         s1        |  -0.0597897 |      0.1852820      | -0.3226957 | 0.7469257 |   |
# |       avgs1       |  -0.3871658 |      1.4162941      | -0.2733654 | 0.7845724 |   |
# | ecgrowth_demeaned |  -0.2211971 |      0.1016678      | -2.1756853 | 0.0295788 | * |
# |   logpop_M_diff   |  5.5635552  |      8.1950217      | 0.6788945  | 0.4972047 |   |
# |  logpopdens_diff  |  5.5636568  |      8.1951376      | 0.6788973  | 0.4972029 |   |
# |   logoutreg_diff  |  0.0636250  |      0.4360956      | 0.1458968  | 0.8840028 |   |
# |   democracy_diff  | -13.0714379 |      6.7547989      | -1.9351335 | 0.0529739 |   |
# |        _con       |  0.0107241  |      0.0048059      | 2.2314311  | 0.0256526 | * |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(74) = 81.533 Prob > Chi2 = 0.257
# Arellano-Bond test for AR(1) in first differences: z = -4.05 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = -0.31 Pr > z =0.756
#
#  m2
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 1501
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 81                       Max obs per group: 12
#  Number of groups = 142                           Avg obs per group: 10.57
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0205587  |      0.0394006      | 0.5217873  | 0.6018184 |   |
# |   L2.onset2COWCS  |  -0.0167023 |      0.0070353      | -2.3740603 | 0.0175937 | * |
# |         s1        |  -0.0746176 |      0.2345560      | -0.3181229 | 0.7503917 |   |
# |       avgs1       |  -0.4475236 |      1.3662150      | -0.3275646 | 0.7432409 |   |
# | ecgrowth_demeaned |  -0.2462242 |      0.1122015      | -2.1944827 | 0.0282007 | * |
# |   logpop_M_diff   |  7.9416787  |      7.8957359      | 1.0058187  | 0.3145028 |   |
# |  logpopdens_diff  |  7.9417822  |      7.8958506      | 1.0058172  | 0.3145035 |   |
# |   logoutreg_diff  |  0.2863932  |      0.4152113      | 0.6897528  | 0.4903496 |   |
# |   democracy_diff  | -15.5913345 |      7.1742113      | -2.1732472 | 0.0297617 | * |
# |        _con       |  0.0115032  |      0.0046774      | 2.4592879  | 0.0139213 | * |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(71) = 86.220 Prob > Chi2 = 0.105
# Arellano-Bond test for AR(1) in first differences: z = -4.05 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 0.13 Pr > z =0.896
#
#  m3
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 1357
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 75                       Max obs per group: 11
#  Number of groups = 142                           Avg obs per group: 9.56
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0259597  |      0.0361105      | 0.7188947  | 0.4722058 |   |
# |   L2.onset2COWCS  |  -0.0104224 |      0.0099065      | -1.0520724 | 0.2927663 |   |
# |   L3.onset2COWCS  |  -0.0106938 |      0.0047460      | -2.2532440 | 0.0242438 | * |
# |         s1        |  0.1485634  |      0.3322704      | 0.4471158  | 0.6547915 |   |
# |       avgs1       |  -0.9282535 |      1.4926257      | -0.6218930 | 0.5340122 |   |
# | ecgrowth_demeaned |  -0.2372526 |      0.1125835      | -2.1073479 | 0.0350874 | * |
# |   logpop_M_diff   |  1.1865028  |      7.9073334      | 0.1500509  | 0.8807244 |   |
# |  logpopdens_diff  |  1.1864564  |      7.9072620      | 0.1500464  | 0.8807280 |   |
# |   logoutreg_diff  |  0.0534051  |      0.5413449      | 0.0986526  | 0.9214141 |   |
# |   democracy_diff  | -11.3250222 |      5.1721290      | -2.1896248 | 0.0285515 | * |
# |        _con       |  0.0134235  |      0.0055539      | 2.4169675  | 0.0156504 | * |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(64) = 49.964 Prob > Chi2 = 0.901
# Arellano-Bond test for AR(1) in first differences: z = -3.96 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = -0.01 Pr > z =0.990
#
#  m4
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 1218
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 69                       Max obs per group: 10
#  Number of groups = 142                           Avg obs per group: 8.58
# +-------------------+------------+---------------------+------------+-----------+----+
# |    onset2COWCS    |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |    |
# +-------------------+------------+---------------------+------------+-----------+----+
# |   L1.onset2COWCS  | 0.0381368  |      0.0492934      | 0.7736686  | 0.4391268 |    |
# |   L2.onset2COWCS  | -0.0076415 |      0.0072431      | -1.0550148 | 0.2914185 |    |
# |   L3.onset2COWCS  | -0.0112140 |      0.0039640      | -2.8289596 | 0.0046700 | ** |
# |   L4.onset2COWCS  | 0.0163670  |      0.0488716      | 0.3348974  | 0.7377025 |    |
# |         s1        | 0.2340759  |      0.3024035      | 0.7740515  | 0.4389003 |    |
# |       avgs1       | -1.1611800 |      1.8487484      | -0.6280898 | 0.5299451 |    |
# | ecgrowth_demeaned | -0.1790242 |      0.1068377      | -1.6756653 | 0.0938038 |    |
# |   logpop_M_diff   | 2.6863927  |      8.0881342      | 0.3321400  | 0.7397836 |    |
# |  logpopdens_diff  | 2.6863509  |      8.0880389      | 0.3321387  | 0.7397845 |    |
# |   logoutreg_diff  | 0.0414388  |      0.5303442      | 0.0781357  | 0.9377201 |    |
# |   democracy_diff  | -6.8545825 |      7.1383555      | -0.9602467 | 0.3369311 |    |
# |        _con       | 0.0100659  |      0.0060683      | 1.6587740  | 0.0971613 |    |
# +-------------------+------------+---------------------+------------+-----------+----+
# Hansen test of overid. restrictions: chi(57) = 47.187 Prob > Chi2 = 0.820
# Arellano-Bond test for AR(1) in first differences: z = -3.76 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = -0.08 Pr > z =0.936
#
#  m5
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 1082
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 63                       Max obs per group: 9
#  Number of groups = 142                           Avg obs per group: 7.62
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0440280  |      0.0908296      | 0.4847322  | 0.6278663 |   |
# |   L2.onset2COWCS  |  -0.0126189 |      0.0055426      | -2.2767166 | 0.0228032 | * |
# |   L3.onset2COWCS  |  -0.0118604 |      0.0068434      | -1.7331147 | 0.0830753 |   |
# |   L4.onset2COWCS  |  0.0143411  |      0.0492016      | 0.2914768  | 0.7706867 |   |
# |   L5.onset2COWCS  |  -0.0615387 |      0.1483684      | -0.4147699 | 0.6783104 |   |
# |         s1        |  0.1667969  |      0.5397474      | 0.3090278  | 0.7573004 |   |
# |       avgs1       |  -0.0912411 |      3.7220576      | -0.0245136 | 0.9804429 |   |
# | ecgrowth_demeaned |  -0.1042410 |      0.1782495      | -0.5848037 | 0.5586797 |   |
# |   logpop_M_diff   |  6.9512404  |      13.5731249     | 0.5121326  | 0.6085582 |   |
# |  logpopdens_diff  |  6.9511876  |      13.5730033     | 0.5121333  | 0.6085577 |   |
# |   logoutreg_diff  |  0.0847697  |      0.9812470      | 0.0863897  | 0.9311566 |   |
# |   democracy_diff  | -14.7850664 |      26.2179496     | -0.5639292 | 0.5728023 |   |
# |        _con       |  0.0080026  |      0.0070712      | 1.1317226  | 0.2577511 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(50) = 65.123 Prob > Chi2 = 0.074
# Arellano-Bond test for AR(1) in first differences: z = -3.08 Pr > z =0.002
# Arellano-Bond test for AR(2) in first differences: z = 0.65 Pr > z =0.517
#
#  m6
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 950
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 57                       Max obs per group: 8
#  Number of groups = 142                           Avg obs per group: 6.69
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0473056  |      0.0699261      | 0.6765080  | 0.4987182 |   |
# |   L2.onset2COWCS  |  -0.0056587 |      0.0058382      | -0.9692534 | 0.3324188 |   |
# |   L3.onset2COWCS  |  -0.0105055 |      0.0060638      | -1.7324808 | 0.0831880 |   |
# |   L4.onset2COWCS  |  0.0189873  |      0.0559572      | 0.3393180  | 0.7343702 |   |
# |   L5.onset2COWCS  |  -0.0835598 |      0.0815874      | -1.0241747 | 0.3057528 |   |
# |   L6.onset2COWCS  |  -0.0689014 |      0.0546612      | -1.2605172 | 0.2074828 |   |
# |         s1        |  0.2958060  |      0.2746407      | 1.0770652  | 0.2814511 |   |
# |       avgs1       |  -0.4206401 |      1.9130497      | -0.2198793 | 0.8259651 |   |
# | ecgrowth_demeaned |  -0.1265277 |      0.1229195      | -1.0293540 | 0.3033133 |   |
# |   logpop_M_diff   |  1.6506459  |      10.4988696     | 0.1572213  | 0.8750704 |   |
# |  logpopdens_diff  |  1.6506247  |      10.4988948     | 0.1572189  | 0.8750723 |   |
# |   logoutreg_diff  |  -0.0384786 |      0.6299741      | -0.0610797 | 0.9512957 |   |
# |   democracy_diff  | -10.8539327 |      11.5820038     | -0.9371377 | 0.3486877 |   |
# |        _con       |  0.0084771  |      0.0096496      | 0.8784846  | 0.3796808 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(43) = 35.188 Prob > Chi2 = 0.796
# Arellano-Bond test for AR(1) in first differences: z = -3.16 Pr > z =0.002
# Arellano-Bond test for AR(2) in first differences: z = 0.91 Pr > z =0.361
#
#  m7
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 819
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 51                       Max obs per group: 7
#  Number of groups = 142                           Avg obs per group: 5.77
# +-------------------+------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  | -0.0033937 |      0.0108858      | -0.3117519 | 0.7552291 |   |
# |   L2.onset2COWCS  | -0.0016738 |      0.0094208      | -0.1776723 | 0.8589804 |   |
# |   L3.onset2COWCS  | -0.0061156 |      0.0098261      | -0.6223812 | 0.5336913 |   |
# |   L4.onset2COWCS  | 0.0522922  |      0.0446651      | 1.1707613  | 0.2416948 |   |
# |   L5.onset2COWCS  | 0.0181146  |      0.0586982      | 0.3086060  | 0.7576213 |   |
# |   L6.onset2COWCS  | -0.0322536 |      0.0489995      | -0.6582444 | 0.5103811 |   |
# |   L7.onset2COWCS  | 0.0453356  |      0.0518912      | 0.8736661  | 0.3823001 |   |
# |         s1        | 0.3971463  |      0.5758954      | 0.6896154  | 0.4904361 |   |
# |       avgs1       | -0.3147945 |      2.5943733      | -0.1213374 | 0.9034238 |   |
# | ecgrowth_demeaned | -0.1250274 |      0.0985283      | -1.2689493 | 0.2044591 |   |
# |   logpop_M_diff   | -2.4615154 |      15.4044081     | -0.1597929 | 0.8730442 |   |
# |  logpopdens_diff  | -2.4615367 |      15.4042643     | -0.1597958 | 0.8730419 |   |
# |   logoutreg_diff  | -0.2984828 |      0.5020436      | -0.5945356 | 0.5521540 |   |
# |   democracy_diff  | -9.5114913 |      13.0438005     | -0.7291963 | 0.4658816 |   |
# |        _con       | 0.0072616  |      0.0073263      | 0.9911687  | 0.3216032 |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(36) = 21.385 Prob > Chi2 = 0.975
# Arellano-Bond test for AR(1) in first differences: z = -3.55 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 1.23 Pr > z =0.218
#
#  m8
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 692
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 45                       Max obs per group: 6
#  Number of groups = 142                           Avg obs per group: 4.87
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  -0.0124935 |      0.0135616      | -0.9212382 | 0.3569261 |   |
# |   L2.onset2COWCS  |  -0.0044521 |      0.0107278      | -0.4150095 | 0.6781349 |   |
# |   L3.onset2COWCS  |  -0.0077218 |      0.0097573      | -0.7913872 | 0.4287181 |   |
# |   L4.onset2COWCS  |  0.0073509  |      0.0600267      | 0.1224611  | 0.9025338 |   |
# |   L5.onset2COWCS  |  0.0021561  |      0.0474470      | 0.0454413  | 0.9637555 |   |
# |   L6.onset2COWCS  |  -0.0059023 |      0.0569364      | -0.1036642 | 0.9174358 |   |
# |   L7.onset2COWCS  |  -0.0004029 |      0.0381537      | -0.0105599 | 0.9915746 |   |
# |   L8.onset2COWCS  |  0.0082043  |      0.0618673      | 0.1326119  | 0.8945003 |   |
# |         s1        |  -0.0774328 |      0.4073963      | -0.1900674 | 0.8492563 |   |
# |       avgs1       |  0.5941373  |      3.0466019      | 0.1950164  | 0.8453801 |   |
# | ecgrowth_demeaned |  -0.1352890 |      0.0701829      | -1.9276635 | 0.0538970 |   |
# |   logpop_M_diff   |  -3.8555042 |      10.1613527     | -0.3794282 | 0.7043699 |   |
# |  logpopdens_diff  |  -3.8555318 |      10.1612815     | -0.3794336 | 0.7043659 |   |
# |   logoutreg_diff  |  -0.1449913 |      0.6016253      | -0.2409994 | 0.8095556 |   |
# |   democracy_diff  | -14.4067190 |      10.6283295     | -1.3555017 | 0.1752578 |   |
# |        _con       |  0.0090443  |      0.0087130      | 1.0380201  | 0.2992607 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(29) = 16.910 Prob > Chi2 = 0.964
# Arellano-Bond test for AR(1) in first differences: z = -3.22 Pr > z =0.001
# Arellano-Bond test for AR(2) in first differences: z = 0.83 Pr > z =0.404
#
#  m9
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 567
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 39                       Max obs per group: 5
#  Number of groups = 142                           Avg obs per group: 3.99
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  -0.0119049 |      0.0080836      | -1.4727219 | 0.1408260 |   |
# |   L2.onset2COWCS  |  -0.0134847 |      0.0102156      | -1.3200150 | 0.1868300 |   |
# |   L3.onset2COWCS  |  -0.0057773 |      0.0094799      | -0.6094246 | 0.5422431 |   |
# |   L4.onset2COWCS  |  0.3521415  |      0.3594521      | 0.9796618  | 0.3272531 |   |
# |   L5.onset2COWCS  |  -0.0117845 |      0.0797698      | -0.1477314 | 0.8825548 |   |
# |   L6.onset2COWCS  |  0.0147584  |      0.0526243      | 0.2804485  | 0.7791335 |   |
# |   L7.onset2COWCS  |  0.0143472  |      0.0442235      | 0.3244245  | 0.7456167 |   |
# |   L8.onset2COWCS  |  -0.0354492 |      0.0736460      | -0.4813460 | 0.6302706 |   |
# |   L9.onset2COWCS  |  0.0273001  |      0.0453119      | 0.6024934  | 0.5468458 |   |
# |         s1        |  -0.2613851 |      0.3061715      | -0.8537212 | 0.3932595 |   |
# |       avgs1       |  0.6201406  |      1.4442565      | 0.4293840  | 0.6676438 |   |
# | ecgrowth_demeaned |  0.0187062  |      0.0598853      | 0.3123668  | 0.7547617 |   |
# |   logpop_M_diff   |  0.8827730  |      11.0240267     | 0.0800772  | 0.9361759 |   |
# |  logpopdens_diff  |  0.8824008  |      11.0238559     | 0.0800447  | 0.9362017 |   |
# |   logoutreg_diff  |  0.1825736  |      0.5577005      | 0.3273685  | 0.7433892 |   |
# |   democracy_diff  | -19.7983924 |      9.9008083      | -1.9996743 | 0.0455354 | * |
# |        _con       |  0.0093468  |      0.0076067      | 1.2287576  | 0.2191627 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(22) = 10.355 Prob > Chi2 = 0.983
# Arellano-Bond test for AR(1) in first differences: z = -3.00 Pr > z =0.003
# Arellano-Bond test for AR(2) in first differences: z = 0.13 Pr > z =0.897
#
#  m10
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 445
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 33                       Max obs per group: 4
#  Number of groups = 142                           Avg obs per group: 3.13
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  -0.0061990 |      0.0120711      | -0.5135411 | 0.6075729 |   |
# |   L2.onset2COWCS  |  -0.0085469 |      0.0122538      | -0.6974919 | 0.4854950 |   |
# |   L3.onset2COWCS  |  0.0024765  |      0.0138961      | 0.1782172  | 0.8585524 |   |
# |   L4.onset2COWCS  |  0.5603254  |      0.4689693      | 1.1948020  | 0.2321644 |   |
# |   L5.onset2COWCS  |  0.1475279  |      0.1218621      | 1.2106130  | 0.2260437 |   |
# |   L6.onset2COWCS  |  0.1621594  |      0.1593203      | 1.0178202  | 0.3087634 |   |
# |   L7.onset2COWCS  |  0.0622786  |      0.1074909      | 0.5793847  | 0.5623297 |   |
# |   L8.onset2COWCS  |  -0.1179334 |      0.0975742      | -1.2086535 | 0.2267960 |   |
# |   L9.onset2COWCS  |  -0.1071904 |      0.1816722      | -0.5900209 | 0.5551766 |   |
# |  L10.onset2COWCS  |  -0.0801748 |      0.1870522      | -0.4286224 | 0.6681980 |   |
# |         s1        |  -0.5199984 |      0.5993040      | -0.8676704 | 0.3855748 |   |
# |       avgs1       |  0.8375651  |      1.6840254      | 0.4973590  | 0.6189359 |   |
# | ecgrowth_demeaned |  0.0385194  |      0.0604722      | 0.6369771  | 0.5241397 |   |
# |   logpop_M_diff   |  5.8412221  |      11.4496142     | 0.5101676  | 0.6099341 |   |
# |  logpopdens_diff  |  5.8410470  |      11.4496759     | 0.5101495  | 0.6099467 |   |
# |   logoutreg_diff  |  0.1396965  |      0.8788414      | 0.1589553  | 0.8737041 |   |
# |   democracy_diff  | -24.3262380 |      12.3786548     | -1.9651762 | 0.0493938 | * |
# |        _con       |  0.0050171  |      0.0121291      | 0.4136425  | 0.6791360 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(15) = 5.395 Prob > Chi2 = 0.988
# Arellano-Bond test for AR(1) in first differences: z = -2.51 Pr > z =0.012
# Arellano-Bond test for AR(2) in first differences: z = -0.13 Pr > z =0.898
#
#  m11
#  Dynamic panel-data estimation, two-step system GMM
#  Group variable: country                          Number of obs = 326
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 27                       Max obs per group: 3
#  Number of groups = 142                           Avg obs per group: 2.30
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  -0.0309253 |      0.0163211      | -1.8948007 | 0.0581188 |   |
# |   L2.onset2COWCS  |  -0.0279760 |      0.0158330      | -1.7669420 | 0.0772379 |   |
# |   L3.onset2COWCS  |  -0.0339212 |      0.0321691      | -1.0544638 | 0.2916706 |   |
# |   L4.onset2COWCS  |  -0.3936746 |      0.5085639      | -0.7740907 | 0.4388772 |   |
# |   L5.onset2COWCS  |  0.0705775  |      0.1289039      | 0.5475203  | 0.5840213 |   |
# |   L6.onset2COWCS  |  -0.0946059 |      0.1421312      | -0.6656235 | 0.5056518 |   |
# |   L7.onset2COWCS  |  -0.1338147 |      0.1514580      | -0.8835104 | 0.3769606 |   |
# |   L8.onset2COWCS  |  -0.0000308 |      0.1976078      | -0.0001556 | 0.9998758 |   |
# |   L9.onset2COWCS  |  0.0182785  |      0.1281611      | 0.1426216  | 0.8865890 |   |
# |  L10.onset2COWCS  |  0.2009392  |      0.3986160      | 0.5040921  | 0.6141967 |   |
# |  L11.onset2COWCS  |  0.1785835  |      0.2831086      | 0.6307952  | 0.5281744 |   |
# |         s1        |  0.4197591  |      0.9623246      | 0.4361928  | 0.6626968 |   |
# |       avgs1       |  0.3655664  |      1.4118726      | 0.2589231  | 0.7956946 |   |
# | ecgrowth_demeaned |  -0.0285112 |      0.0813017      | -0.3506845 | 0.7258251 |   |
# |   logpop_M_diff   |  15.6422476 |      19.3694372     | 0.8075737  | 0.4193360 |   |
# |  logpopdens_diff  |  15.6420922 |      19.3692566     | 0.8075732  | 0.4193363 |   |
# |   logoutreg_diff  |  0.4630500  |      1.0860624      | 0.4263567  | 0.6698479 |   |
# |   democracy_diff  | -20.0681836 |      15.6498121     | -1.2823274 | 0.1997278 |   |
# |        _con       |  0.0181440  |      0.0108077      | 1.6788028  | 0.0931905 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(8) = 1.339 Prob > Chi2 = 0.995
# Arellano-Bond test for AR(1) in first differences: z = -1.90 Pr > z =0.058
# Arellano-Bond test for AR(2) in first differences: z = 0.02 Pr > z =0.987
#
# models are sorted by bic
# +-------------------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |     variables     |    m1    |    m2    |    m3    |    m4    |    m5    |    m6    |    m7    |    m8    |    m9    |   m10    |   m11    |
# +-------------------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# |   L1.onset2COWCS  |  0.020   |  0.021   |  0.026   |  0.038   |  0.044   |  0.047   | -0.003   | -0.012   | -0.012   | -0.006   | -0.031   |
# |                   | (0.032)  | (0.039)  | (0.036)  | (0.049)  | (0.091)  | (0.070)  | (0.011)  | (0.014)  | (0.008)  | (0.012)  | (0.016)  |
# |   L2.onset2COWCS  |          | -0.017*  | -0.010   | -0.008   | -0.013*  | -0.006   | -0.002   | -0.004   | -0.013   | -0.009   | -0.028   |
# |                   |          | (0.007)  | (0.010)  | (0.007)  | (0.006)  | (0.006)  | (0.009)  | (0.011)  | (0.010)  | (0.012)  | (0.016)  |
# |   L3.onset2COWCS  |          |          | -0.011*  | -0.011** | -0.012   | -0.011   | -0.006   | -0.008   | -0.006   |  0.002   | -0.034   |
# |                   |          |          | (0.005)  | (0.004)  | (0.007)  | (0.006)  | (0.010)  | (0.010)  | (0.009)  | (0.014)  | (0.032)  |
# |   L4.onset2COWCS  |          |          |          |  0.016   |  0.014   |  0.019   |  0.052   |  0.007   |  0.352   |  0.560   | -0.394   |
# |                   |          |          |          | (0.049)  | (0.049)  | (0.056)  | (0.045)  | (0.060)  | (0.359)  | (0.469)  | (0.509)  |
# |   L5.onset2COWCS  |          |          |          |          | -0.062   | -0.084   |  0.018   |  0.002   | -0.012   |  0.148   |  0.071   |
# |                   |          |          |          |          | (0.148)  | (0.082)  | (0.059)  | (0.047)  | (0.080)  | (0.122)  | (0.129)  |
# |   L6.onset2COWCS  |          |          |          |          |          | -0.069   | -0.032   | -0.006   |  0.015   |  0.162   | -0.095   |
# |                   |          |          |          |          |          | (0.055)  | (0.049)  | (0.057)  | (0.053)  | (0.159)  | (0.142)  |
# |   L7.onset2COWCS  |          |          |          |          |          |          |  0.045   | -0.000   |  0.014   |  0.062   | -0.134   |
# |                   |          |          |          |          |          |          | (0.052)  | (0.038)  | (0.044)  | (0.107)  | (0.151)  |
# |   L8.onset2COWCS  |          |          |          |          |          |          |          |  0.008   | -0.035   | -0.118   | -0.000   |
# |                   |          |          |          |          |          |          |          | (0.062)  | (0.074)  | (0.098)  | (0.198)  |
# |   L9.onset2COWCS  |          |          |          |          |          |          |          |          |  0.027   | -0.107   |  0.018   |
# |                   |          |          |          |          |          |          |          |          | (0.045)  | (0.182)  | (0.128)  |
# |  L10.onset2COWCS  |          |          |          |          |          |          |          |          |          | -0.080   |  0.201   |
# |                   |          |          |          |          |          |          |          |          |          | (0.187)  | (0.399)  |
# |  L11.onset2COWCS  |          |          |          |          |          |          |          |          |          |          |  0.179   |
# |                   |          |          |          |          |          |          |          |          |          |          | (0.283)  |
# |         s1        | -0.060   | -0.075   |  0.149   |  0.234   |  0.167   |  0.296   |  0.397   | -0.077   | -0.261   | -0.520   |  0.420   |
# |                   | (0.185)  | (0.235)  | (0.332)  | (0.302)  | (0.540)  | (0.275)  | (0.576)  | (0.407)  | (0.306)  | (0.599)  | (0.962)  |
# |       avgs1       | -0.387   | -0.448   | -0.928   | -1.161   | -0.091   | -0.421   | -0.315   |  0.594   |  0.620   |  0.838   |  0.366   |
# |                   | (1.416)  | (1.366)  | (1.493)  | (1.849)  | (3.722)  | (1.913)  | (2.594)  | (3.047)  | (1.444)  | (1.684)  | (1.412)  |
# | ecgrowth_demeaned | -0.221*  | -0.246*  | -0.237*  | -0.179   | -0.104   | -0.127   | -0.125   | -0.135   |  0.019   |  0.039   | -0.029   |
# |                   | (0.102)  | (0.112)  | (0.113)  | (0.107)  | (0.178)  | (0.123)  | (0.099)  | (0.070)  | (0.060)  | (0.060)  | (0.081)  |
# |   logpop_M_diff   |  5.564   |  7.942   |  1.187   |  2.686   |  6.951   |  1.651   | -2.462   | -3.856   |  0.883   |  5.841   | 15.642   |
# |                   | (8.195)  | (7.896)  | (7.907)  | (8.088)  | (13.573) | (10.499) | (15.404) | (10.161) | (11.024) | (11.450) | (19.369) |
# |  logpopdens_diff  |  5.564   |  7.942   |  1.186   |  2.686   |  6.951   |  1.651   | -2.462   | -3.856   |  0.882   |  5.841   | 15.642   |
# |                   | (8.195)  | (7.896)  | (7.907)  | (8.088)  | (13.573) | (10.499) | (15.404) | (10.161) | (11.024) | (11.450) | (19.369) |
# |   logoutreg_diff  |  0.064   |  0.286   |  0.053   |  0.041   |  0.085   | -0.038   | -0.298   | -0.145   |  0.183   |  0.140   |  0.463   |
# |                   | (0.436)  | (0.415)  | (0.541)  | (0.530)  | (0.981)  | (0.630)  | (0.502)  | (0.602)  | (0.558)  | (0.879)  | (1.086)  |
# |   democracy_diff  | -13.071  | -15.591* | -11.325* | -6.855   | -14.785  | -10.854  | -9.511   | -14.407  | -19.798* | -24.326* | -20.068  |
# |                   | (6.755)  | (7.174)  | (5.172)  | (7.138)  | (26.218) | (11.582) | (13.044) | (10.628) | (9.901)  | (12.379) | (15.650) |
# |        _con       |  0.011*  |  0.012*  |  0.013*  |  0.010   |  0.008   |  0.008   |  0.007   |  0.009   |  0.009   |  0.005   |  0.018   |
# |                   | (0.005)  | (0.005)  | (0.006)  | (0.006)  | (0.007)  | (0.010)  | (0.007)  | (0.009)  | (0.008)  | (0.012)  | (0.011)  |
# +-------------------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+----------+
# HTML output named "output.html" is located in folder /Users/zwanran/Desktop/ECMA31320/final/ECMA31320-project/code/Internal_IV
#
#
# MMSC_LU scores:
# +-------+---------+----------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | model |   aic   |   bic    |   hqic   | command str                                                                                                                                                                                                                                                                                                                                      |
# +-------+---------+----------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   m1  | -68.467 | -473.925 | -233.830 |  onset2COWCS  L1.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                                                                                                      |
# |   m2  | -57.780 | -440.380 | -214.634 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                                                                                      |
# |   m3  | -80.036 | -418.883 | -219.745 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                                                                      |
# |   m4  | -68.813 | -364.901 | -191.637 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                                                      |
# |   m5  | -36.877 | -291.192 | -143.079 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                                      |
# |   m6  | -52.812 | -266.497 | -142.700 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                                      |
# |   m7  | -52.615 | -226.814 | -126.502 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                                      |
# |   m8  | -43.090 | -179.278 | -101.396 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                                      |
# |   m9  | -35.645 | -135.473 | -78.852  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                                      |
# |  m10  | -26.605 | -92.174  | -55.353  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  L10.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |                     |
# |  m11  | -16.661 | -50.743  | -31.842  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  L10.onset2COWCS  L11.onset2COWCS  s1  avgs1  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(avgs1) |    |
# +-------+---------+----------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#  m1
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1646
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 56                       Max obs per group: 13
#  Number of groups = 142                           Avg obs per group: 11.59
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0375823  |      0.0407822      | 0.9215364  | 0.3567704 |   |
# |         s1        |  -0.1811539 |      0.0990799      | -1.8283615 | 0.0674953 |   |
# |       avgs1       | -17.9723822 |      27.9036637     | -0.6440868 | 0.5195191 |   |
# | ecgrowth_demeaned |  -0.2063138 |      0.1049170      | -1.9664479 | 0.0492469 | * |
# |   logpop_M_diff   |  -2.4723214 |      8.3927135      | -0.2945795 | 0.7683151 |   |
# |  logpopdens_diff  |  -2.4726555 |      8.3928174      | -0.2946157 | 0.7682875 |   |
# |   logoutreg_diff  |  0.6360690  |      0.5787005      | 1.0991334  | 0.2717099 |   |
# |   democracy_diff  | -11.4076458 |      5.2098377      | -2.1896356 | 0.0285507 | * |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(48) = 43.845 Prob > Chi2 = 0.644
# Arellano-Bond test for AR(1) in first differences: z = -3.98 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 0.09 Pr > z =0.925
#
#  m2
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1501
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 54                       Max obs per group: 12
#  Number of groups = 142                           Avg obs per group: 10.57
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  0.0329704  |      0.0379797      | 0.8681047  | 0.3853370 |   |
# |   L2.onset2COWCS  |  -0.0048179 |      0.0095523      | -0.5043647 | 0.6140051 |   |
# |         s1        |  -0.3212323 |      0.1585379      | -2.0262176 | 0.0427425 | * |
# |       avgs1       | -16.5704773 |      25.0849091     | -0.6605755 | 0.5088846 |   |
# | ecgrowth_demeaned |  -0.2393376 |      0.1196583      | -2.0001757 | 0.0454813 | * |
# |   logpop_M_diff   |  -2.9528566 |      9.0680141      | -0.3256343 | 0.7447010 |   |
# |  logpopdens_diff  |  -2.9529503 |      9.0679489      | -0.3256470 | 0.7446915 |   |
# |   logoutreg_diff  |  0.8000747  |      0.4509667      | 1.7741326  | 0.0760412 |   |
# |   democracy_diff  | -12.1929942 |      6.2762718      | -1.9427129 | 0.0520509 |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(45) = 39.668 Prob > Chi2 = 0.697
# Arellano-Bond test for AR(1) in first differences: z = -4.05 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 0.16 Pr > z =0.869
#
#  m3
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1357
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 50                       Max obs per group: 11
#  Number of groups = 142                           Avg obs per group: 9.56
# +-------------------+-------------+---------------------+------------+-----------+-----+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |     |
# +-------------------+-------------+---------------------+------------+-----------+-----+
# |   L1.onset2COWCS  |  -0.2852526 |      0.1127992      | -2.5288520 | 0.0114436 |  *  |
# |   L2.onset2COWCS  |  -0.3128433 |      0.0905257      | -3.4558502 | 0.0005486 | *** |
# |   L3.onset2COWCS  |  -0.3281934 |      0.0891226      | -3.6824939 | 0.0002310 | *** |
# |         s1        |  -0.2483691 |      0.2181542      | -1.1385027 | 0.2549106 |     |
# |       avgs1       |  -4.5478015 |      39.9317279     | -0.1138894 | 0.9093254 |     |
# | ecgrowth_demeaned |  -0.1892119 |      0.1197104      | -1.5805798 | 0.1139742 |     |
# |   logpop_M_diff   |  -3.4577881 |      8.1103154      | -0.4263445 | 0.6698569 |     |
# |  logpopdens_diff  |  -3.4577566 |      8.1102408      | -0.4263445 | 0.6698568 |     |
# |   logoutreg_diff  |  0.2796224  |      0.6842709      | 0.4086429  | 0.6828018 |     |
# |   democracy_diff  | -12.7805949 |      6.2087446      | -2.0584830 | 0.0395438 |  *  |
# +-------------------+-------------+---------------------+------------+-----------+-----+
# Hansen test of overid. restrictions: chi(40) = 28.256 Prob > Chi2 = 0.918
# Arellano-Bond test for AR(1) in first differences: z = -3.27 Pr > z =0.001
# Arellano-Bond test for AR(2) in first differences: z = 0.60 Pr > z =0.550
#
#  m4
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1218
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 46                       Max obs per group: 10
#  Number of groups = 142                           Avg obs per group: 8.58
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |      z      |   P>|z|   |     |
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# |   L1.onset2COWCS  |  -0.9893084 |      0.1060087      |  -9.3323356 | 0.0000000 | *** |
# |   L2.onset2COWCS  |  -0.9882855 |      0.0974358      | -10.1429406 | 0.0000000 | *** |
# |   L3.onset2COWCS  |  -0.9905268 |      0.0956851      | -10.3519407 | 0.0000000 | *** |
# |   L4.onset2COWCS  |  -0.9368653 |      0.1093676      |  -8.5662052 | 0.0000000 | *** |
# |         s1        |  -0.2591873 |      0.3866711      |  -0.6703042 | 0.5026639 |     |
# |       avgs1       | -22.3898602 |      25.2202705     |  -0.8877724 | 0.3746632 |     |
# | ecgrowth_demeaned |  -0.1172831 |      0.0697533      |  -1.6813990 | 0.0926854 |     |
# |   logpop_M_diff   |  2.6190441  |      6.8735786      |  0.3810306  | 0.7031805 |     |
# |  logpopdens_diff  |  2.6185413  |      6.8734657      |  0.3809637  | 0.7032301 |     |
# |   logoutreg_diff  |  0.3003543  |      0.6609871      |  0.4544027  | 0.6495390 |     |
# |   democracy_diff  |  -8.5066350 |      7.2743404      |  -1.1694029 | 0.2422413 |     |
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# Hansen test of overid. restrictions: chi(35) = 26.488 Prob > Chi2 = 0.849
# Arellano-Bond test for AR(1) in first differences: z = 0.60 Pr > z =0.546
# Arellano-Bond test for AR(2) in first differences: z = 1.25 Pr > z =0.212
#
#  m5
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1082
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 42                       Max obs per group: 9
#  Number of groups = 142                           Avg obs per group: 7.62
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |      z      |   P>|z|   |     |
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# |   L1.onset2COWCS  |  -0.9465556 |      0.0532493      | -17.7759094 | 0.0000000 | *** |
# |   L2.onset2COWCS  |  -0.9543997 |      0.0467073      | -20.4336417 | 0.0000000 | *** |
# |   L3.onset2COWCS  |  -0.9573659 |      0.0452843      | -21.1412241 | 0.0000000 | *** |
# |   L4.onset2COWCS  |  -0.8799816 |      0.0881069      |  -9.9876596 | 0.0000000 | *** |
# |   L5.onset2COWCS  |  -0.1045675 |      0.0821540      |  -1.2728231 | 0.2030808 |     |
# |         s1        |  -0.1867266 |      0.3284049      |  -0.5685865 | 0.5696368 |     |
# |       avgs1       | -23.9568543 |      28.8344527     |  -0.8308413 | 0.4060633 |     |
# | ecgrowth_demeaned |  -0.0859698 |      0.0745945      |  -1.1524958 | 0.2491174 |     |
# |   logpop_M_diff   |  3.7747574  |      7.0670022      |  0.5341384  | 0.5932458 |     |
# |  logpopdens_diff  |  3.7746308  |      7.0669489      |  0.5341245  | 0.5932554 |     |
# |   logoutreg_diff  |  0.1522554  |      0.6550540      |  0.2324318  | 0.8162027 |     |
# |   democracy_diff  | -15.0085347 |      11.9700234     |  -1.2538434 | 0.2098989 |     |
# +-------------------+-------------+---------------------+-------------+-----------+-----+
# Hansen test of overid. restrictions: chi(30) = 30.853 Prob > Chi2 = 0.423
# Arellano-Bond test for AR(1) in first differences: z = 1.04 Pr > z =0.296
# Arellano-Bond test for AR(2) in first differences: z = 1.20 Pr > z =0.228
#
#  m6
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 950
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 38                       Max obs per group: 8
#  Number of groups = 142                           Avg obs per group: 6.69
# +-------------------+-------------+---------------------+------------+-----------+-----+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |     |
# +-------------------+-------------+---------------------+------------+-----------+-----+
# |   L1.onset2COWCS  |  -0.9390611 |      0.1204343      | -7.7972875 | 0.0000000 | *** |
# |   L2.onset2COWCS  |  -0.9453643 |      0.1118173      | -8.4545414 | 0.0000000 | *** |
# |   L3.onset2COWCS  |  -0.9511243 |      0.1100710      | -8.6410039 | 0.0000000 | *** |
# |   L4.onset2COWCS  |  -0.8545064 |      0.1519926      | -5.6220245 | 0.0000000 | *** |
# |   L5.onset2COWCS  |  -0.1011496 |      0.0749559      | -1.3494543 | 0.1771911 |     |
# |   L6.onset2COWCS  |  -0.0384396 |      0.0580827      | -0.6618071 | 0.5080948 |     |
# |         s1        |  -0.2491296 |      0.5381994      | -0.4628946 | 0.6434399 |     |
# |       avgs1       | -26.6023528 |      28.1050826     | -0.9465317 | 0.3438774 |     |
# | ecgrowth_demeaned |  -0.1193117 |      0.0807147      | -1.4781891 | 0.1393572 |     |
# |   logpop_M_diff   |  0.8954064  |      7.2676973      | 0.1232036  | 0.9019459 |     |
# |  logpopdens_diff  |  0.8952358  |      7.2676923      | 0.1231802  | 0.9019644 |     |
# |   logoutreg_diff  |  0.2401074  |      0.7949602      | 0.3020370  | 0.7626238 |     |
# |   democracy_diff  | -13.1385545 |      7.9416734      | -1.6543811 | 0.0980501 |     |
# +-------------------+-------------+---------------------+------------+-----------+-----+
# Hansen test of overid. restrictions: chi(25) = 20.292 Prob > Chi2 = 0.731
# Arellano-Bond test for AR(1) in first differences: z = 0.22 Pr > z =0.824
# Arellano-Bond test for AR(2) in first differences: z = 1.10 Pr > z =0.272
#
#  m7
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 819
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 34                       Max obs per group: 7
#  Number of groups = 142                           Avg obs per group: 5.77
# +-------------------+-------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |    coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+-------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  |  -0.5439237 |      0.3697857      | -1.4709161 | 0.1413138 |   |
# |   L2.onset2COWCS  |  -0.5444464 |      0.3676745      | -1.4807834 | 0.1386643 |   |
# |   L3.onset2COWCS  |  -0.5466272 |      0.3684150      | -1.4837268 | 0.1378814 |   |
# |   L4.onset2COWCS  |  -0.5200096 |      0.3701875      | -1.4047194 | 0.1601047 |   |
# |   L5.onset2COWCS  |  -0.0984478 |      0.1082941      | -0.9090779 | 0.3633090 |   |
# |   L6.onset2COWCS  |  -0.0262213 |      0.0486164      | -0.5393507 | 0.5896449 |   |
# |   L7.onset2COWCS  |  -0.0565791 |      0.1152157      | -0.4910710 | 0.6233762 |   |
# ...
# | model | command str                                                                                                                                                                                                                                                                                                                                                            |
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |  m11  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  L10.onset2COWCS  L11.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel |
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#  m1
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1646
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 69                       Max obs per group: 13
#  Number of groups = 142                           Avg obs per group: 11.59
# +-------------------+------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  | 0.0375131  |      0.0441793      | 0.8491113  | 0.3958193 |   |
# |        s10        | -0.6397030 |      1.4252762      | -0.4488274 | 0.6535562 |   |
# |    trans_outp_p   | 0.1389588  |      0.1880077      | 0.7391122  | 0.4598389 |   |
# | ecgrowth_demeaned | -0.1775781 |      0.0906941      | -1.9579893 | 0.0502313 |   |
# |   logpop_M_diff   | -1.5847505 |      5.8070514      | -0.2729011 | 0.7849293 |   |
# |  logpopdens_diff  | -1.5847258 |      5.8070648      | -0.2728962 | 0.7849330 |   |
# |   logoutreg_diff  | -0.1610640 |      0.7956313      | -0.2024355 | 0.8395763 |   |
# |   democracy_diff  | -6.5761291 |      4.2752083      | -1.5382009 | 0.1239995 |   |
# |       t_1993      | 0.0274356  |      0.0192757      | 1.4233214  | 0.1546430 |   |
# |       t_1994      | 0.0352061  |      0.0236211      | 1.4904482  | 0.1361064 |   |
# |       t_1995      | 0.0021228  |      0.0522910      | 0.0405952  | 0.9676186 |   |
# |       t_1996      | 0.0167867  |      0.0564382      | 0.2974348  | 0.7661346 |   |
# |       t_1997      | -2.2772591 |      1.6683841      | -1.3649489 | 0.1722691 |   |
# |       t_1998      | -1.1458104 |      1.5137070      | -0.7569565 | 0.4490759 |   |
# |       t_1999      | -0.8931256 |      1.2264182      | -0.7282390 | 0.4664673 |   |
# |       t_2000      | -0.5274654 |      0.8206902      | -0.6427095 | 0.5204126 |   |
# |       t_2001      | -0.0135298 |      0.1953312      | -0.0692660 | 0.9447779 |   |
# |       t_2002      | 0.6396784  |      0.6586901      | 0.9711371  | 0.3314800 |   |
# |       t_2003      | 1.1137128  |      1.2434080      | 0.8956938  | 0.3704163 |   |
# |       t_2004      | 1.4562100  |      1.6736427      | 0.8700842  | 0.3842544 |   |
# |       t_2005      | 1.6475888  |      1.8663234      | 0.8827992  | 0.3773448 |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(48) = 38.087 Prob > Chi2 = 0.847
# Arellano-Bond test for AR(1) in first differences: z = -3.96 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 0.01 Pr > z =0.988
#
#  m2
#  Dynamic panel-data estimation, two-step difference GMM
#  Group variable: country                          Number of obs = 1501
#  Time variable: t                                 Min obs per group: 0
#  Number of instruments = 79                       Max obs per group: 12
#  Number of groups = 142                           Avg obs per group: 10.57
# +-------------------+------------+---------------------+------------+-----------+---+
# |    onset2COWCS    |   coef.    | Corrected Std. Err. |     z      |   P>|z|   |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# |   L1.onset2COWCS  | 0.0367422  |      0.0434740      | 0.8451540  | 0.3980248 |   |
# |   L2.onset2COWCS  | -0.0027392 |      0.0065214      | -0.4200375 | 0.6744581 |   |
# |        s10        | -0.0651416 |      1.1961165      | -0.0544609 | 0.9565679 |   |
# |    trans_outp_p   | 0.1152971  |      0.2117076      | 0.5446054  | 0.5860250 |   |
# | ecgrowth_demeaned | -0.1929228 |      0.0942729      | -2.0464280 | 0.0407143 | * |
# |   logpop_M_diff   | -0.3519566 |      7.0367599      | -0.0500169 | 0.9601090 |   |
# |  logpopdens_diff  | -0.3519379 |      7.0367199      | -0.0500145 | 0.9601108 |   |
# |   logoutreg_diff  | -0.0092269 |      0.6682300      | -0.0138079 | 0.9889832 |   |
# |   democracy_diff  | -8.9227807 |      4.8627794      | -1.8349137 | 0.0665185 |   |
# |       t_1994      | 0.0091419  |      0.0075310      | 1.2139093  | 0.2247824 |   |
# |       t_1995      | -0.0221822 |      0.0470663      | -0.4712978 | 0.6374281 |   |
# |       t_1996      | -0.0075637 |      0.0508458      | -0.1487574 | 0.8817450 |   |
# |       t_1997      | -2.1557515 |      1.7492714      | -1.2323711 | 0.2178105 |   |
# |       t_1998      | -1.0389274 |      1.5863681      | -0.6549094 | 0.5125261 |   |
# |       t_1999      | -0.8059311 |      1.2926098      | -0.6234914 | 0.5329617 |   |
# |       t_2000      | -0.4726982 |      0.8451411      | -0.5593127 | 0.5759483 |   |
# |       t_2001      | -0.0044137 |      0.1512381      | -0.0291835 | 0.9767182 |   |
# |       t_2002      | 0.5934729  |      0.7318718      | 0.8108974  | 0.4174246 |   |
# |       t_2003      | 1.0253397  |      1.2893397      | 0.7952441  | 0.4264715 |   |
# |       t_2004      | 1.3397116  |      1.6978297      | 0.7890730  | 0.4300693 |   |
# |       t_2005      | 1.5191995  |      1.9062014      | 0.7969774  | 0.4254641 |   |
# +-------------------+------------+---------------------+------------+-----------+---+
# Hansen test of overid. restrictions: chi(58) = 36.055 Prob > Chi2 = 0.990
# Arellano-Bond test for AR(1) in first differences: z = -4.01 Pr > z =0.000
# Arellano-Bond test for AR(2) in first differences: z = 0.04 Pr > z =0.966
#
# models are sorted by bic
# +-------------------+---------+---------+
# |     variables     |    m2   |    m1   |
# +-------------------+---------+---------+
# |   L1.onset2COWCS  |  0.037  |  0.038  |
# |                   | (0.043) | (0.044) |
# |   L2.onset2COWCS  | -0.003  |         |
# |                   | (0.007) |         |
# |        s10        | -0.065  | -0.640  |
# |                   | (1.196) | (1.425) |
# |    trans_outp_p   |  0.115  |  0.139  |
# |                   | (0.212) | (0.188) |
# | ecgrowth_demeaned | -0.193* | -0.178  |
# |                   | (0.094) | (0.091) |
# |   logpop_M_diff   | -0.352  | -1.585  |
# |                   | (7.037) | (5.807) |
# |  logpopdens_diff  | -0.352  | -1.585  |
# |                   | (7.037) | (5.807) |
# |   logoutreg_diff  | -0.009  | -0.161  |
# |                   | (0.668) | (0.796) |
# |   democracy_diff  | -8.923  | -6.576  |
# |                   | (4.863) | (4.275) |
# |       t_1994      |  0.009  |  0.035  |
# |                   | (0.008) | (0.024) |
# |       t_1995      | -0.022  |  0.002  |
# |                   | (0.047) | (0.052) |
# |       t_1996      | -0.008  |  0.017  |
# |                   | (0.051) | (0.056) |
# |       t_1997      | -2.156  | -2.277  |
# |                   | (1.749) | (1.668) |
# |       t_1998      | -1.039  | -1.146  |
# |                   | (1.586) | (1.514) |
# |       t_1999      | -0.806  | -0.893  |
# |                   | (1.293) | (1.226) |
# |       t_2000      | -0.473  | -0.527  |
# |                   | (0.845) | (0.821) |
# |       t_2001      | -0.004  | -0.014  |
# |                   | (0.151) | (0.195) |
# |       t_2002      |  0.593  |  0.640  |
# |                   | (0.732) | (0.659) |
# |       t_2003      |  1.025  |  1.114  |
# |                   | (1.289) | (1.243) |
# |       t_2004      |  1.340  |  1.456  |
# |                   | (1.698) | (1.674) |
# |       t_2005      |  1.519  |  1.648  |
# |                   | (1.906) | (1.866) |
# |       t_1993      |         |  0.027  |
# |                   |         | (0.019) |
# +-------------------+---------+---------+
# HTML output named "output.html" is located in folder /Users/zwanran/Desktop/ECMA31320/final/ECMA31320-project/code/Internal_IV
#
#
# MMSC_LU scores:
# +-------+---------+----------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | model |   aic   |   bic    |   hqic   | command str                                                                                                                                                                                                                   |
# +-------+---------+----------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   m2  | -79.945 | -388.150 | -206.299 |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm |
# |   m1  | -57.913 | -317.406 | -163.746 |  onset2COWCS  L1.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                 |
# +-------+---------+----------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# The following model(s) did not pass specification tests:
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | model | command str                                                                                                                                                                                                                                                                                                                                                                     |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |   m3  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                                                                                                   |
# |   m4  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                                                                                   |
# |   m5  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                                                                   |
# |   m6  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                                                   |
# |   m7  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                                   |
# |   m8  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                                   |
# |   m9  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                                   |
# |  m10  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  L10.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm                  |
# |  m11  |  onset2COWCS  L1.onset2COWCS  L2.onset2COWCS  L3.onset2COWCS  L4.onset2COWCS  L5.onset2COWCS  L6.onset2COWCS  L7.onset2COWCS  L8.onset2COWCS  L9.onset2COWCS  L10.onset2COWCS  L11.onset2COWCS  s10  trans_outp_p  ecgrowth_demeaned  logpop_M_diff  logpopdens_diff  logoutreg_diff  democracy_diff | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(trans_outp_p) |  nolevel timedumm |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
for idx in range(len(results_list)):
    print("========Predictor = ", predictor_list[idx], "========")
    sys.stdout = open(str(path).replace("code/Internal_IV", "output/Internal_IV/") +  predictor_list[idx] + ".txt", 'wt')
    print_results(results_list[idx])
# Out:
# ========Predictor =  gvcomix ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.048222  0.036888  1.307263  0.191123
# 1              s1     2.554468  3.656845  0.698544  0.484837
# 2           avgs1    -2.629226  3.554176 -0.739757  0.459448
# 3        ecgrowth    -0.095577  0.152230 -0.627848  0.530103
# 4        logpop_M     0.120985  0.061098  1.980185  0.047683   *
# 5      logpopdens    -0.053437  0.147177 -0.363080  0.716545
# 6       logoutreg    -0.450222  0.500298 -0.899907  0.368170
# 7            _con     0.078306  0.086990  0.900171  0.368029
# AR(1) test P value:  0.04959487197025249
# AR(2) test P value:  0.9298475207023643
# Hansen test P value:  0.6569328923149437
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.054148   0.037958  1.426539  0.153713
# 1              s1     2.893515   3.944553  0.733547  0.463225
# 2           avgs1   -11.560000  20.943313 -0.551966  0.580972
# 3        ecgrowth    -0.088944   0.186619 -0.476607  0.633642
# 4        logpop_M     0.107001   0.076819  1.392897  0.163651
# 5      logpopdens    -0.027963   0.193789 -0.144295  0.885267
# 6       logoutreg    -0.723064   0.799237 -0.904694  0.365628
# AR(1) test P value:  0.06999308425990926
# AR(2) test P value:  0.9886978269851922
# Hansen test P value:  0.10868518607364874
#
#
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.048608  0.036181  1.343483  0.179116
# 1              s1     2.482831  3.882988  0.639413  0.522555
# 2  trans_outp_p_x     0.253346  0.188895  1.341202  0.179855
# 3        ecgrowth    -0.087937  0.203657 -0.431787  0.665896
# 4        logpop_M     0.164601  0.057904  2.842673  0.004474  **
# 5      logpopdens    -0.003945  0.136979 -0.028799  0.977025
# 6       logoutreg    -0.360932  0.249739 -1.445235  0.148392
# 7            _con     0.043128  0.041659  1.035267  0.300544
# AR(1) test P value:  0.05813289279447388
# AR(2) test P value:  0.9309313297770299
# Hansen test P value:  0.0763160942806208
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.045805  0.036159  1.266775  0.205236
# 1               s1     2.300960  3.772435  0.609940  0.541901
# 2   trans_outp_p_x     0.215425  0.106363  2.025367  0.042830   *
# 3         ecgrowth    -0.081875  0.149537 -0.547524  0.584019
# 4         logpop_M     0.133296  0.063601  2.095825  0.036098   *
# 5       logpopdens    -0.021398  0.131159 -0.163146  0.870403
# 6        logoutreg    -1.139857  0.938546 -1.214492  0.224560
# 7           t_1993     0.005569  0.041245  0.135015  0.892600
# 8           t_1994    -0.008219  0.015074 -0.545235  0.585592
# 9           t_1995    -0.022135  0.008046 -2.751159  0.005938  **
# 10          t_1996    -0.006467  0.013381 -0.483278  0.628898
# 11          t_1997    -0.022412  0.010368 -2.161737  0.030638   *
# 12          t_1998     0.025458  0.040677  0.625857  0.531409
# 13          t_1999     0.003270  0.028728  0.113820  0.909381
# 14          t_2000    -0.011878  0.017585 -0.675501  0.499358
# 15          t_2001    -0.018045  0.017533 -1.029159  0.303405
# 16          t_2002    -0.008278  0.027241 -0.303876  0.761223
# 17          t_2003    -0.003132  0.029062 -0.107756  0.914189
# 18          t_2004    -0.002642  0.014922 -0.177091  0.859437
# 19          t_2005     0.011142  0.034920  0.319064  0.749678
# 20          t_2006    -0.025137  0.008451 -2.974514  0.002935  **
# 21          t_2007    -0.006725  0.024393 -0.275695  0.782782
# 22          t_2008     0.001903  0.030065  0.063306  0.949523
# 23            _con     0.185944  0.134915  1.378229  0.168133
# AR(1) test P value:  0.04686570625349395
# AR(2) test P value:  0.8782872075641691
# Hansen test P value:  0.3565703337856416
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.054708  0.036374  1.504021  0.132576
# 1              s1     2.953069  3.968352  0.744155  0.456783
# 2  trans_outp_p_x     0.258141  0.114864  2.247351  0.024618   *
# 3        ecgrowth    -0.075327  0.186857 -0.403125  0.686856
# 4        logpop_M     0.141736  0.071369  1.985943  0.047040   *
# 5      logpopdens    -0.020135  0.199405 -0.100975  0.919571
# 6       logoutreg    -0.845291  0.965056 -0.875899  0.381085
# AR(1) test P value:  0.07117413254590348
# AR(2) test P value:  0.9419547672550634
# Hansen test P value:  0.05669163178275516
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.054983  0.038548  1.426335  0.153772
# 1               s1     3.059877  3.472938  0.881063  0.378284
# 2   trans_outp_p_x     0.277271  0.185331  1.496084  0.134632
# 3         ecgrowth    -0.085094  0.161146 -0.528057  0.597460
# 4         logpop_M     0.134143  0.072735  1.844275  0.065143
# 5       logpopdens     0.034276  0.132811  0.258082  0.796344
# 6        logoutreg    -0.957954  1.068222 -0.896774  0.369839
# 7           t_1993     0.914298  0.841230  1.086858  0.277100
# 8           t_1994     1.617364  1.474510  1.096883  0.272693
# 9           t_1995     2.292261  2.177238  1.052830  0.292419
# 10          t_1996     2.884620  2.665030  1.082397  0.279076
# 11          t_1997     3.247361  3.115967  1.042168  0.297334
# 12          t_1998     4.022805  3.803098  1.057770  0.290160
# 13          t_1999     4.518919  4.000976  1.129454  0.258706
# 14          t_2000     5.019210  4.122962  1.217380  0.223460
# 15          t_2001     4.483205  3.504019  1.279447  0.200740
# 16          t_2002     4.347729  3.303492  1.316101  0.188140
# 17          t_2003     4.446653  3.283245  1.354347  0.175626
# 18          t_2004     4.824653  3.315387  1.455231  0.145605
# 19          t_2005     5.376153  3.416280  1.573686  0.115560
# 20          t_2006     5.751379  3.650104  1.575675  0.115101
# 21          t_2007     6.134408  3.825949  1.603369  0.108853
# 22          t_2008     6.180133  3.944286  1.566857  0.117148
# AR(1) test P value:  0.03942912541757512
# AR(2) test P value:  0.9454688869853388
# Hansen test P value:  0.35047488010795147
#
#
# ========Predictor =  gvcobp ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.055830  0.039142  1.426345  0.153769
# 1              s1     4.302185  2.640299  1.629431  0.103222
# 2           avgs1    -7.442658  6.303040 -1.180805  0.237680
# 3        ecgrowth    -0.156285  0.060941 -2.564539  0.010331   *
# 4        logpop_M     0.119972  0.062062  1.933109  0.053223
# 5      logpopdens    -0.024119  0.120738 -0.199767  0.841663
# 6       logoutreg    -0.081820  0.234514 -0.348893  0.727170
# 7            _con     0.015774  0.040125  0.393120  0.694231
# AR(1) test P value:  6.599823581586357e-06
# AR(2) test P value:  0.7126334093603235
# Hansen test P value:  0.15675973458874626
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.429169   0.089285 -4.806753  1.534014e-06  ***
# 1  L2.onset2COWCS    -0.476659   0.085309 -5.587464  2.304094e-08  ***
# 2  L3.onset2COWCS    -0.511653   0.098863 -5.175359  2.274728e-07  ***
# 3              s1    10.535977   4.882576  2.157873  3.093772e-02    *
# 4           avgs1    52.904284  88.784733  0.595871  5.512611e-01
# 5        ecgrowth    -0.095466   0.055298 -1.726392  8.427694e-02
# 6        logpop_M     0.045333   0.050199  0.903062  3.664929e-01
# 7      logpopdens    -0.094804   0.105816 -0.895933  3.702885e-01
# 8       logoutreg     0.148779   0.417524  0.356336  7.215893e-01
# AR(1) test P value:  2.0361781801838613e-05
# AR(2) test P value:  0.33569376635644477
# Hansen test P value:  0.8576471235451363
#
#
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.057591  0.040157  1.434143  0.151531
# 1              s1     3.714413  2.423546  1.532636  0.125366
# 2  trans_outp_p_x     0.182892  0.085718  2.133639  0.032872   *
# 3        ecgrowth    -0.170066  0.069689 -2.440360  0.014673   *
# 4        logpop_M     0.158877  0.071404  2.225044  0.026078   *
# 5      logpopdens    -0.001016  0.113292 -0.008972  0.992841
# 6       logoutreg    -0.248090  0.233714 -1.061511  0.288458
# 7            _con     0.032013  0.040229  0.795784  0.426157
# AR(1) test P value:  6.752707103408992e-06
# AR(2) test P value:  0.7223883641710789
# Hansen test P value:  0.06646173948173295
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.050033  0.037285  1.341909  0.179626
# 1               s1     4.777649  2.822558  1.692666  0.090519
# 2   trans_outp_p_x     0.153765  0.077143  1.993247  0.046234   *
# 3         ecgrowth    -0.140317  0.053397 -2.627812  0.008594  **
# 4         logpop_M     0.118053  0.057717  2.045371  0.040818   *
# 5       logpopdens    -0.004186  0.096436 -0.043409  0.965375
# 6        logoutreg    -0.563888  0.464531 -1.213886  0.224791
# 7           t_1993    -0.011695  0.010979 -1.065255  0.286761
# 8           t_1994    -0.012714  0.011032 -1.152435  0.249142
# 9           t_1995    -0.017869  0.009505 -1.879840  0.060130
# 10          t_1996    -0.000795  0.012805 -0.062064  0.950512
# 11          t_1997    -0.020009  0.008945 -2.236864  0.025295   *
# 12          t_1998     0.008430  0.016767  0.502786  0.615115
# 13          t_1999    -0.011560  0.008538 -1.353990  0.175739
# 14          t_2000    -0.017115  0.010400 -1.645687  0.099828
# 15          t_2001    -0.019129  0.011420 -1.675054  0.093924
# 16          t_2002    -0.016112  0.008108 -1.987170  0.046904   *
# 17          t_2003    -0.014558  0.008882 -1.639043  0.101204
# 18          t_2004    -0.010201  0.010599 -0.962487  0.335805
# 19          t_2005    -0.003755  0.010521 -0.356928  0.721146
# 20          t_2006    -0.021525  0.010004 -2.151746  0.031417   *
# 21          t_2007    -0.015101  0.008383 -1.801495  0.071625
# 22          t_2008    -0.010316  0.008763 -1.177204  0.239114
# 23            _con     0.100137  0.080402  1.245457  0.212964
# AR(1) test P value:  5.6552830650745895e-06
# AR(2) test P value:  0.6647131665366641
# Hansen test P value:  0.8499383226708026
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.418671  0.088682 -4.721063  2.346156e-06  ***
# 1  L2.onset2COWCS    -0.469314  0.084432 -5.558498  2.721067e-08  ***
# 2  L3.onset2COWCS    -0.501493  0.096962 -5.172065  2.315212e-07  ***
# 3              s1    10.551106  5.057831  2.086093  3.697020e-02    *
# 4  trans_outp_p_x     0.139726  0.081327  1.718090  8.578024e-02
# 5        ecgrowth    -0.080524  0.068925 -1.168278  2.426946e-01
# 6        logpop_M     0.092029  0.065428  1.406567  1.595559e-01
# 7      logpopdens    -0.120844  0.111660 -1.082254  2.791396e-01
# 8       logoutreg    -0.056741  0.383092 -0.148113  8.822536e-01
# AR(1) test P value:  1.7024538236020943e-05
# AR(2) test P value:  0.3221206996183521
# Hansen test P value:  0.8126850429160868
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.036776  0.039156  0.939223  0.347616
# 1   L2.onset2COWCS    -0.041743  0.023725 -1.759435  0.078504
# 2               s1     7.775687  5.163476  1.505902  0.132092
# 3   trans_outp_p_x     0.205205  0.087823  2.336572  0.019461   *
# 4         ecgrowth    -0.141402  0.065039 -2.174107  0.029697   *
# 5         logpop_M     0.189936  0.068395  2.777040  0.005486  **
# 6       logpopdens    -0.044571  0.111537 -0.399609  0.689445
# 7        logoutreg    -0.430571  0.698218 -0.616671  0.537451
# 8           t_1994     0.258554  0.146385  1.766252  0.077354
# 9           t_1995     0.385632  0.208552  1.849092  0.064444
# 10          t_1996     0.605350  0.346107  1.749028  0.080286
# 11          t_1997     0.753810  0.461330  1.633994  0.102260
# 12          t_1998     1.444489  0.859217  1.681169  0.092730
# 13          t_1999     1.909072  1.142495  1.670967  0.094728
# 14          t_2000     2.550531  1.514886  1.683645  0.092250
# 15          t_2001     2.534323  1.548634  1.636489  0.101737
# 16          t_2002     3.022005  1.867605  1.618118  0.105637
# 17          t_2003     3.491539  2.157013  1.618691  0.105514
# 18          t_2004     3.947720  2.449684  1.611522  0.107066
# 19          t_2005     4.272763  2.688573  1.589231  0.112008
# 20          t_2006     4.434393  2.812602  1.576616  0.114884
# 21          t_2007     4.500236  2.865714  1.570372  0.116329
# 22          t_2008     4.445448  2.843627  1.563302  0.117982
# AR(1) test P value:  1.6128575740064814e-05
# AR(2) test P value:  0.8492835995446346
# Hansen test P value:  0.8434946037032621
#
#
# ========Predictor =  gvcofp ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.073456  0.047902  1.533487  0.125156
# 1  L2.onset2COWCS    -0.005483  0.008465 -0.647684  0.517189
# 2  L3.onset2COWCS    -0.006487  0.004774 -1.358924  0.174171
# 3              s1    -1.433453  1.683517 -0.851464  0.394512
# 4           avgs1     1.067827  1.636209  0.652622  0.514000
# 5        ecgrowth    -0.154414  0.070082 -2.203333  0.027571   *
# 6        logpop_M     0.097736  0.051267  1.906424  0.056595
# 7      logpopdens     0.013489  0.076751  0.175750  0.860491
# 8       logoutreg    -0.191121  0.197380 -0.968287  0.332901
# 9            _con     0.032629  0.034640  0.941954  0.346216
# AR(1) test P value:  3.733332037333555e-05
# AR(2) test P value:  0.6577800189692358
# Hansen test P value:  0.21662291711350912
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.509529   0.101633 -5.013426  5.346940e-07  ***
# 1  L2.onset2COWCS    -0.540263   0.086100 -6.274845  3.499832e-10  ***
# 2  L3.onset2COWCS    -0.587322   0.091859 -6.393733  1.618837e-10  ***
# 3              s1    -1.746276   1.236926 -1.411787  1.580127e-01
# 4           avgs1    21.470487  13.327374  1.611007  1.071783e-01
# 5        ecgrowth    -0.082549   0.054843 -1.505189  1.322754e-01
# 6        logpop_M     0.073200   0.061858  1.183353  2.366691e-01
# 7      logpopdens    -0.002650   0.125705 -0.021084  9.831788e-01
# 8       logoutreg     0.352744   0.474533  0.743350  4.572700e-01
# AR(1) test P value:  0.0012472056411412138
# AR(2) test P value:  0.6888605526470797
# Hansen test P value:  0.2222125279176721
#
#
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.041628  0.049262  0.845019  0.398100
# 1   L2.onset2COWCS    -0.010410  0.007763 -1.340926  0.179944
# 2   L3.onset2COWCS    -0.009788  0.009415 -1.039593  0.298529
# 3   L4.onset2COWCS    -0.007073  0.058461 -0.120987  0.903701
# 4   L5.onset2COWCS    -0.107283  0.135435 -0.792131  0.428284
# 5               s1    -0.930291  1.051805 -0.884471  0.376442
# 6   trans_outp_p_x     0.128943  0.096352  1.338257  0.180813
# 7         ecgrowth    -0.126761  0.085123 -1.489148  0.136448
# 8         logpop_M     0.124527  0.081461  1.528670  0.126346
# 9       logpopdens    -0.031414  0.093843 -0.334749  0.737814
# 10       logoutreg    -0.730437  0.347069 -2.104586  0.035327   *
# 11            _con     0.121496  0.061326  1.981172  0.047572   *
# AR(1) test P value:  0.0001344157776146023
# AR(2) test P value:  0.9349037626058032
# Hansen test P value:  0.26772628568691814
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.049778  0.038217  1.302491  0.192749
# 1               s1    -0.698653  1.219893 -0.572717  0.566836
# 2   trans_outp_p_x     0.193529  0.065141  2.970951  0.002969  **
# 3         ecgrowth    -0.118051  0.058662 -2.012404  0.044177   *
# 4         logpop_M     0.129232  0.041023  3.150246  0.001631  **
# 5       logpopdens     0.009040  0.070462  0.128290  0.897920
# 6        logoutreg    -0.422456  0.499967 -0.844968  0.398129
# 7           t_1993    -0.007488  0.006442 -1.162368  0.245086
# 8           t_1994    -0.000505  0.011364 -0.044425  0.964565
# 9           t_1995    -0.010087  0.006595 -1.529366  0.126174
# 10          t_1996    -0.000970  0.010067 -0.096383  0.923216
# 11          t_1997    -0.011560  0.007771 -1.487542  0.136872
# 12          t_1998     0.012497  0.016851  0.741639  0.458306
# 13          t_1999    -0.007344  0.005842 -1.257094  0.208719
# 14          t_2000    -0.006782  0.012146 -0.558422  0.576556
# 15          t_2001    -0.011336  0.009595 -1.181396  0.237446
# 16          t_2002    -0.014166  0.005368 -2.638819  0.008320  **
# 17          t_2003    -0.008637  0.006508 -1.327033  0.184498
# 18          t_2004     0.000781  0.009288  0.084126  0.932956
# 19          t_2005    -0.003784  0.009366 -0.403986  0.686223
# 20          t_2006    -0.010665  0.009296 -1.147323  0.251248
# 21          t_2007    -0.008681  0.005467 -1.587805  0.112330
# 22          t_2008    -0.006057  0.006900 -0.877705  0.380104
# 23            _con     0.069241  0.085977  0.805346  0.420620
# AR(1) test P value:  8.92645522012292e-06
# AR(2) test P value:  0.6179432408118556
# Hansen test P value:  0.4279070709206054
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.506634  0.104066 -4.868381  1.125164e-06  ***
# 1  L2.onset2COWCS    -0.538702  0.087149 -6.181361  6.355145e-10  ***
# 2  L3.onset2COWCS    -0.584328  0.091287 -6.401016  1.543461e-10  ***
# 3              s1    -1.963488  1.254868 -1.564697  1.176539e-01
# 4  trans_outp_p_x     0.063516  0.062324  1.019125  3.081437e-01
# 5        ecgrowth    -0.095285  0.061878 -1.539881  1.235894e-01
# 6        logpop_M     0.108495  0.074638  1.453615  1.460530e-01
# 7      logpopdens    -0.010699  0.142939 -0.074853  9.403319e-01
# 8       logoutreg     0.316719  0.531208  0.596224  5.510255e-01
# AR(1) test P value:  0.0014870787476075882
# AR(2) test P value:  0.6836357404564641
# Hansen test P value:  0.06774822163999472
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.047147  0.037054  1.272382  0.203237
# 1   L2.onset2COWCS    -0.018434  0.016741 -1.101127  0.270842
# 2               s1    -0.892600  0.566668 -1.575171  0.115217
# 3   trans_outp_p_x     0.210182  0.113666  1.849112  0.064442
# 4         ecgrowth    -0.123341  0.071472 -1.725731  0.084396
# 5         logpop_M     0.165114  0.069943  2.360685  0.018241   *
# 6       logpopdens     0.021673  0.112229  0.193119  0.846866
# 7        logoutreg     0.059660  0.331380  0.180034  0.857126
# 8           t_1994     0.171005  0.114573  1.492540  0.135558
# 9           t_1995     0.385436  0.278880  1.382086  0.166945
# 10          t_1996     0.647575  0.480953  1.346440  0.178161
# 11          t_1997     0.959701  0.757561  1.266831  0.205216
# 12          t_1998     1.408769  1.131204  1.245372  0.212995
# 13          t_1999     1.804681  1.444052  1.249734  0.211397
# 14          t_2000     2.207231  1.751108  1.260477  0.207497
# 15          t_2001     2.473398  1.955454  1.264871  0.205917
# 16          t_2002     2.785790  2.162500  1.288227  0.197667
# 17          t_2003     3.097059  2.372906  1.305176  0.191833
# 18          t_2004     3.373103  2.548583  1.323521  0.185662
# 19          t_2005     3.606338  2.701861  1.334761  0.181955
# 20          t_2006     3.783749  2.818702  1.342373  0.179475
# 21          t_2007     3.914757  2.892953  1.353205  0.175990
# 22          t_2008     3.994027  2.920150  1.367747  0.171391
# AR(1) test P value:  2.831879287001364e-05
# AR(2) test P value:  0.8760397611200335
# Hansen test P value:  0.5920090018534374
