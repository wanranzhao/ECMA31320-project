# %%
import pandas as pd
from pydynpd import regression
import pathlib
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %% [markdown]
# # Questions
# 1. perform one-step GMM estimation rather than the default two-step GMM estimation.
#
# # Assumption tests
# ## AR
# We expect to reject AR(1) but not AR(2)
# ## Overidentification
# A suggested rule of thumb is that any p-value between 0.1 and 0.25 should be fine as it is reasonably larger than a significance level of 0.05 and it is reasonably small enough to not suspect severe p-value inflation. In that case, system GMM without time dummy is the best result that we can get.

# %%
unstationary = 'ecgrowth logpop_M logpopdens logoutreg'
stationary = 'logmountain ethnic_fractionalization religion_fractionalization language_fractionalization leg_british opec'

path = pathlib.Path().resolve()
iv = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/transportIV_file.csv", na_values= '#DIV/0!')
# We do not introduce stationary controls under most circumstance. 
# Usually they do not change the results a lot, but that should be verified in the robustness check.
# No time FE if we are using world-level average gvc participation as external IV

# %%
def load_data(predictor = "gvcomix"):
    df = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/" + predictor + "_transformed1.csv", na_values= '#DIV/0!')
    df = pd.merge(df, iv, on=["country", "t"])
    label = le.fit_transform(df['country'])
    df.drop('country', axis=1, inplace=True)
    df['country'] = label
    df.fillna(0, inplace=True)
    return df

# %%
def reg(method=" ", additional_cntrl = False, time = False, iv = 'trans_outp_p_x'):
    # System GMM by default (method = "nolevel" produces difference GMM)
    # No stationary controls by default
    # IV = transport by default
    command_str = 'onset2COWCS L(1:?).onset2COWCS s1 ' + iv + ' ' + unstationary + ' '
    if additional_cntrl:
        command_str = command_str + stationary
    command_str = command_str + ' | gmm(onset2COWCS, 2:3) gmm(s1, 2:3) iv(' + iv + ') | ' + ' ' + method
    if time:
         command_str = command_str + ' timedumm'
    mydpd = regression.abond(command_str, df, ['country', 't']);
    return mydpd #.models[0] #.regression_table

# %%
def all_reg():
    # world average gvc participation IV.
    # Do not add time dummy
    ## System GMM
    m1 = reg(iv = 'avgs1');
    ## Difference GMM
    m2 = reg(iv = 'avgs1', method="nolevel");

    # Transport IV
    ## System GMM
    m3 = reg();
    m4 = reg(time = True);
    ## Difference GMM
    m5 = reg(method = "nolevel");
    m6 = reg(time = True, method="nolevel");

    results = [m1, m2, m3, m4, m5, m6]
    return results

# %%
def print_results(results):
    for idx in range(len(results)):
        if idx == 0:
            print("IV = World Average; Sys.")
        if idx == 1:
            print("IV = World Average; Dif.")
        if idx == 3:
            print("IV = Transport; Sys.")
        if idx == 4:
            print("IV = World Average; Sys; t-FE.")
        if idx == 5:
            print("IV = Transport; Dif.")
        if idx == 6:
            print("IV = World Average; Dif; t-FE.")
        m = results[idx].models[0]
        print(m.regression_table)
        print("AR(1) test P value: ", end=" ")
        print(m.AR_list[0].P_value)
        print("AR(2) test P value: ", end=" ")
        print(m.AR_list[1].P_value)
        print("Hansen test P value: ", end=" ")
        print(m.hansen.p_value)
        print("\n")

# %%
# %%capture
predictor_list = ["gvcomix", "gvcobp", "gvcofp"]
results_list = []
for predictor in predictor_list:
    df = load_data(predictor);
    results_list.append(all_reg());

# %%
for idx in range(len(results_list)):
    print("========Predictor = ", predictor_list[idx], "========")
    print_results(results_list[idx])
# Out:
# ========Predictor =  gvcomix ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.048222  0.036888  1.307263  0.191123
# 1              s1     2.554468  3.656845  0.698544  0.484837
# 2           avgs1    -2.629226  3.554176 -0.739757  0.459448
# 3        ecgrowth    -0.095577  0.152230 -0.627848  0.530103
# 4        logpop_M     0.120985  0.061098  1.980185  0.047683   *
# 5      logpopdens    -0.053437  0.147177 -0.363080  0.716545
# 6       logoutreg    -0.450222  0.500298 -0.899907  0.368170
# 7            _con     0.078306  0.086990  0.900171  0.368029
# AR(1) test P value:  0.04959487197025249
# AR(2) test P value:  0.9298475207023643
# Hansen test P value:  0.6569328923149437
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.054148   0.037958  1.426539  0.153713
# 1              s1     2.893515   3.944553  0.733547  0.463225
# 2           avgs1   -11.560000  20.943313 -0.551966  0.580972
# 3        ecgrowth    -0.088944   0.186619 -0.476607  0.633642
# 4        logpop_M     0.107001   0.076819  1.392897  0.163651
# 5      logpopdens    -0.027963   0.193789 -0.144295  0.885267
# 6       logoutreg    -0.723064   0.799237 -0.904694  0.365628
# AR(1) test P value:  0.06999308425990926
# AR(2) test P value:  0.9886978269851922
# Hansen test P value:  0.10868518607364874
#
#
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.048480  0.040905  1.185191  0.235942
# 1              s1     2.535390  3.252078  0.779622  0.435614
# 2  trans_outp_p_x     0.025196  0.023150  1.088372  0.276431
# 3        ecgrowth    -0.083603  0.112984 -0.739954  0.459328
# 4        logpop_M     0.153882  0.102640  1.499247  0.133810
# 5      logpopdens    -0.074517  0.136700 -0.545112  0.585676
# 6       logoutreg    -0.290886  0.275951 -1.054122  0.291827
# 7            _con     0.033554  0.048761  0.688143  0.491362
# AR(1) test P value:  0.03482457691494543
# AR(2) test P value:  0.9536131445967376
# Hansen test P value:  0.2986065123300131
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.044516  0.037849  1.176170  0.239527
# 1               s1     2.214928  3.566306  0.621071  0.534553
# 2   trans_outp_p_x     0.016618  0.018150  0.915631  0.359860
# 3         ecgrowth    -0.089995  0.157306 -0.572100  0.567254
# 4         logpop_M     0.102944  0.059684  1.724819  0.084560
# 5       logpopdens    -0.033729  0.134179 -0.251372  0.801527
# 6        logoutreg    -1.085884  1.102131 -0.985259  0.324497
# 7           t_1993     0.001335  0.047666  0.028017  0.977649
# 8           t_1994    -0.008948  0.020487 -0.436764  0.662282
# 9           t_1995    -0.024189  0.009041 -2.675492  0.007462  **
# 10          t_1996    -0.007883  0.013556 -0.581536  0.560879
# 11          t_1997    -0.021964  0.011491 -1.911410  0.055952
# 12          t_1998     0.024908  0.042838  0.581447  0.560939
# 13          t_1999     0.002366  0.036528  0.064767  0.948360
# 14          t_2000    -0.016213  0.018602 -0.871550  0.383454
# 15          t_2001    -0.019558  0.020037 -0.976090  0.329020
# 16          t_2002    -0.011134  0.031453 -0.353974  0.723358
# 17          t_2003    -0.006325  0.034935 -0.181050  0.856328
# 18          t_2004    -0.005171  0.025103 -0.205986  0.836802
# 19          t_2005     0.007075  0.041595  0.170103  0.864929
# 20          t_2006    -0.026946  0.008525 -3.160831  0.001573  **
# 21          t_2007    -0.009666  0.027950 -0.345822  0.729476
# 22          t_2008    -0.001813  0.034206 -0.052998  0.957734
# 23            _con     0.184041  0.158719  1.159540  0.246236
# AR(1) test P value:  0.03783341963919041
# AR(2) test P value:  0.8610926769103628
# Hansen test P value:  0.6067955393412015
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.056347  0.038734  1.454718  0.145747
# 1              s1     2.928709  3.978882  0.736063  0.461692
# 2  trans_outp_p_x     0.018255  0.031683  0.576168  0.564502
# 3        ecgrowth    -0.088656  0.194506 -0.455804  0.648531
# 4        logpop_M     0.119897  0.088495  1.354851  0.175465
# 5      logpopdens    -0.040863  0.193985 -0.210650  0.833160
# 6       logoutreg    -0.665548  1.122576 -0.592876  0.553264
# AR(1) test P value:  0.06817075420013335
# AR(2) test P value:  0.9229275970301498
# Hansen test P value:  0.06640374405620098
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.053500  0.038546  1.387953  0.165151
# 1               s1     3.039758  3.685895  0.824700  0.409542
# 2   trans_outp_p_x     0.023327  0.040276  0.579182  0.562466
# 3         ecgrowth    -0.078398  0.184667 -0.424537  0.671174
# 4         logpop_M     0.117557  0.084798  1.386313  0.165651
# 5       logpopdens    -0.020837  0.151144 -0.137864  0.890348
# 6        logoutreg    -0.765815  1.163073 -0.658441  0.510255
# 7           t_1993     0.487025  1.058834  0.459964  0.645542
# 8           t_1994     0.765892  1.905704  0.401894  0.687762
# 9           t_1995     1.009728  2.742232  0.368214  0.712714
# 10          t_1996     1.203329  3.411101  0.352769  0.724262
# 11          t_1997     1.192891  3.909696  0.305111  0.760282
# 12          t_1998     1.613730  4.756528  0.339266  0.734409
# 13          t_1999     1.766073  5.050820  0.349661  0.726593
# 14          t_2000     1.932919  5.141103  0.375973  0.706937
# 15          t_2001     1.078652  4.061937  0.265551  0.790585
# 16          t_2002     0.623771  3.349018  0.186255  0.852245
# 17          t_2003     0.239297  2.847025  0.084051  0.933016
# 18          t_2004    -0.032553  2.560223 -0.012715  0.989855
# 19          t_2005    -0.296610  2.408440 -0.123154  0.901985
# 20          t_2006    -0.529700  2.680751 -0.197594  0.843363
# 21          t_2007    -0.558485  2.902274 -0.192430  0.847405
# 22          t_2008    -0.726795  3.144287 -0.231148  0.817200
# AR(1) test P value:  0.04934037109408085
# AR(2) test P value:  0.7415139725361102
# Hansen test P value:  0.12414351696252912
#
#
# ========Predictor =  gvcobp ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.055830  0.039142  1.426345  0.153769
# 1              s1     4.302185  2.640299  1.629431  0.103222
# 2           avgs1    -7.442658  6.303040 -1.180805  0.237680
# 3        ecgrowth    -0.156285  0.060941 -2.564539  0.010331   *
# 4        logpop_M     0.119972  0.062062  1.933109  0.053223
# 5      logpopdens    -0.024119  0.120738 -0.199767  0.841663
# 6       logoutreg    -0.081820  0.234514 -0.348893  0.727170
# 7            _con     0.015774  0.040125  0.393120  0.694231
# AR(1) test P value:  6.599823581586357e-06
# AR(2) test P value:  0.7126334093603235
# Hansen test P value:  0.15675973458874626
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.429169   0.089285 -4.806753  1.534014e-06  ***
# 1  L2.onset2COWCS    -0.476659   0.085309 -5.587464  2.304094e-08  ***
# 2  L3.onset2COWCS    -0.511653   0.098863 -5.175359  2.274728e-07  ***
# 3              s1    10.535977   4.882576  2.157873  3.093772e-02    *
# 4           avgs1    52.904284  88.784733  0.595871  5.512611e-01
# 5        ecgrowth    -0.095466   0.055298 -1.726392  8.427694e-02
# 6        logpop_M     0.045333   0.050199  0.903062  3.664929e-01
# 7      logpopdens    -0.094804   0.105816 -0.895933  3.702885e-01
# 8       logoutreg     0.148779   0.417524  0.356336  7.215893e-01
# AR(1) test P value:  2.0361781801838613e-05
# AR(2) test P value:  0.33569376635644477
# Hansen test P value:  0.8576471235451363
#
#
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.044849  0.041221  1.088001  0.276595
# 1   L2.onset2COWCS    -0.005337  0.005579 -0.956640  0.338749
# 2   L3.onset2COWCS    -0.009515  0.008264 -1.151392  0.249571
# 3   L4.onset2COWCS     0.037165  0.065549  0.566982  0.570727
# 4   L5.onset2COWCS    -0.078556  0.173038 -0.453980  0.649843
# 5               s1     4.655157  4.073646  1.142749  0.253143
# 6   trans_outp_p_x     0.005832  0.013165  0.443002  0.657765
# 7         ecgrowth    -0.108381  0.077374 -1.400740  0.161292
# 8         logpop_M     0.075673  0.061794  1.224603  0.220725
# 9       logpopdens    -0.003040  0.129908 -0.023401  0.981330
# 10       logoutreg    -0.243922  0.199813 -1.220751  0.222180
# 11            _con     0.038717  0.036280  1.067147  0.285905
# AR(1) test P value:  8.413286636109155e-05
# AR(2) test P value:  0.8891112850073668
# Hansen test P value:  0.5489053427506834
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.050411  0.037113  1.358325  0.174361
# 1               s1     4.548899  2.707091  1.680364  0.092886
# 2   trans_outp_p_x     0.016963  0.014405  1.177561  0.238972
# 3         ecgrowth    -0.140337  0.062450 -2.247211  0.024627   *
# 4         logpop_M     0.092901  0.055788  1.665247  0.095863
# 5       logpopdens     0.025463  0.102028  0.249567  0.802922
# 6        logoutreg    -0.343372  0.450342 -0.762468  0.445781
# 7           t_1993    -0.013134  0.010585 -1.240878  0.214651
# 8           t_1994    -0.012619  0.011385 -1.108396  0.267691
# 9           t_1995    -0.017934  0.009149 -1.960176  0.049975   *
# 10          t_1996    -0.000061  0.013344 -0.004608  0.996323
# 11          t_1997    -0.019628  0.009386 -2.091078  0.036521   *
# 12          t_1998     0.004376  0.015860  0.275899  0.782626
# 13          t_1999    -0.011452  0.009373 -1.221901  0.221745
# 14          t_2000    -0.015694  0.010323 -1.520346  0.128424
# 15          t_2001    -0.017425  0.011829 -1.473059  0.140735
# 16          t_2002    -0.016164  0.008125 -1.989530  0.046643   *
# 17          t_2003    -0.014375  0.008371 -1.717126  0.085956
# 18          t_2004    -0.010429  0.010808 -0.964888  0.334601
# 19          t_2005    -0.007799  0.010052 -0.775842  0.437843
# 20          t_2006    -0.020027  0.009280 -2.158036  0.030925   *
# 21          t_2007    -0.015778  0.008225 -1.918127  0.055095
# 22          t_2008    -0.013253  0.008702 -1.523010  0.127756
# 23            _con     0.063035  0.079411  0.793781  0.427323
# AR(1) test P value:  6.057537684174646e-06
# AR(2) test P value:  0.6636012284760646
# Hansen test P value:  0.743247249032651
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.427672  0.087823 -4.869682  1.117781e-06  ***
# 1  L2.onset2COWCS    -0.475655  0.084193 -5.649591  1.608300e-08  ***
# 2  L3.onset2COWCS    -0.508467  0.096660 -5.260366  1.437692e-07  ***
# 3              s1    10.578298  4.966689  2.129849  3.318408e-02    *
# 4  trans_outp_p_x    -0.002454  0.018309 -0.134052  8.933611e-01
# 5        ecgrowth    -0.102374  0.055196 -1.854732  6.363452e-02
# 6        logpop_M     0.058936  0.051727  1.139382  2.545440e-01
# 7      logpopdens    -0.107614  0.109501 -0.982772  3.257197e-01
# 8       logoutreg    -0.030477  0.357457 -0.085262  9.320534e-01
# AR(1) test P value:  2.0218111444146268e-05
# AR(2) test P value:  0.3235232451517871
# Hansen test P value:  0.9009117840963533
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.039128  0.040501  0.966100  0.333994
# 1   L2.onset2COWCS    -0.044032  0.024063 -1.829882  0.067268
# 2               s1     8.337417  5.010408  1.664020  0.096109
# 3   trans_outp_p_x     0.008171  0.017997  0.453994  0.649833
# 4         ecgrowth    -0.137334  0.074011 -1.855597  0.063511
# 5         logpop_M     0.091658  0.058792  1.559028  0.118990
# 6       logpopdens     0.000220  0.108770  0.002026  0.998384
# 7        logoutreg    -0.063099  0.477478 -0.132150  0.894866
# 8           t_1994     0.159580  0.154542  1.032597  0.301793
# 9           t_1995     0.115667  0.280831  0.411874  0.680432
# 10          t_1996     0.146173  0.505808  0.288989  0.772590
# 11          t_1997     0.070274  0.741022  0.094834  0.924447
# 12          t_1998     0.535167  1.235419  0.433187  0.664879
# 13          t_1999     0.766847  1.544973  0.496350  0.619647
# 14          t_2000     1.199060  1.838755  0.652105  0.514334
# 15          t_2001     0.930129  1.822519  0.510353  0.609804
# 16          t_2002     1.202668  1.941158  0.619562  0.535546
# 17          t_2003     1.484446  2.020735  0.734607  0.462579
# 18          t_2004     1.777721  2.076527  0.856103  0.391941
# 19          t_2005     1.956363  2.083385  0.939031  0.347715
# 20          t_2006     2.013241  2.080943  0.967466  0.333311
# 21          t_2007     1.992167  2.069893  0.962449  0.335824
# 22          t_2008     1.872768  2.043115  0.916624  0.359340
# AR(1) test P value:  1.4133524360495488e-05
# AR(2) test P value:  0.7541433617505613
# Hansen test P value:  0.7922593146232652
#
#
# ========Predictor =  gvcofp ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.073456  0.047902  1.533487  0.125156
# 1  L2.onset2COWCS    -0.005483  0.008465 -0.647684  0.517189
# 2  L3.onset2COWCS    -0.006487  0.004774 -1.358923  0.174171
# 3              s1    -1.433454  1.683517 -0.851464  0.394512
# 4           avgs1     1.067827  1.636209  0.652623  0.514000
# 5        ecgrowth    -0.154414  0.070082 -2.203333  0.027571   *
# 6        logpop_M     0.097736  0.051267  1.906424  0.056595
# 7      logpopdens     0.013489  0.076751  0.175749  0.860491
# 8       logoutreg    -0.191121  0.197380 -0.968288  0.332901
# 9            _con     0.032629  0.034640  0.941955  0.346216
# AR(1) test P value:  3.733331652845327e-05
# AR(2) test P value:  0.657779992441569
# Hansen test P value:  0.21662351550703096
#
#
# IV = World Average; Dif.
#          variable  coefficient    std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.509529   0.101633 -5.013426  5.346940e-07  ***
# 1  L2.onset2COWCS    -0.540263   0.086100 -6.274845  3.499832e-10  ***
# 2  L3.onset2COWCS    -0.587322   0.091859 -6.393733  1.618837e-10  ***
# 3              s1    -1.746276   1.236926 -1.411787  1.580127e-01
# 4           avgs1    21.470488  13.327375  1.611007  1.071783e-01
# 5        ecgrowth    -0.082549   0.054843 -1.505189  1.322754e-01
# 6        logpop_M     0.073200   0.061858  1.183353  2.366691e-01
# 7      logpopdens    -0.002650   0.125705 -0.021084  9.831788e-01
# 8       logoutreg     0.352744   0.474533  0.743350  4.572700e-01
# AR(1) test P value:  0.0012472056343606258
# AR(2) test P value:  0.6888605440857084
# Hansen test P value:  0.2222125432757157
#
#
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.067326  0.049123  1.370546  0.170516
# 1   L2.onset2COWCS    -0.018923  0.012762 -1.482758  0.138139
# 2   L3.onset2COWCS    -0.016359  0.011157 -1.466284  0.142571
# 3   L4.onset2COWCS    -0.048000  0.053017 -0.905375  0.365267
# 4               s1    -1.593142  1.083542 -1.470309  0.141478
# 5   trans_outp_p_x     0.005082  0.016884  0.300990  0.763422
# 6         ecgrowth    -0.106737  0.082917 -1.287276  0.197998
# 7         logpop_M     0.053669  0.067170  0.799011  0.424284
# 8       logpopdens     0.060191  0.075734  0.794769  0.426748
# 9        logoutreg    -0.430755  0.316653 -1.360338  0.173723
# 10            _con     0.074427  0.057185  1.301515  0.193082
# AR(1) test P value:  9.969407918196387e-05
# AR(2) test P value:  0.6495438478931241
# Hansen test P value:  0.8454006074981245
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.051065  0.038507  1.326120  0.184800
# 1               s1    -0.810239  1.415750 -0.572304  0.567116
# 2   trans_outp_p_x     0.012332  0.011096  1.111368  0.266410
# 3         ecgrowth    -0.139408  0.057834 -2.410466  0.015932   *
# 4         logpop_M     0.114208  0.049966  2.285722  0.022271   *
# 5       logpopdens    -0.016018  0.077163 -0.207593  0.835547
# 6        logoutreg    -0.300475  0.536103 -0.560479  0.575153
# 7           t_1993    -0.009173  0.007826 -1.172157  0.241134
# 8           t_1994    -0.000657  0.012134 -0.054114  0.956844
# 9           t_1995    -0.010992  0.006994 -1.571687  0.116023
# 10          t_1996     0.001836  0.011033  0.166376  0.867861
# 11          t_1997    -0.013970  0.006836 -2.043540  0.040999   *
# 12          t_1998     0.009929  0.014935  0.664833  0.506158
# 13          t_1999    -0.010401  0.006048 -1.719790  0.085471
# 14          t_2000    -0.008217  0.012080 -0.680246  0.496349
# 15          t_2001    -0.013969  0.008397 -1.663599  0.096192
# 16          t_2002    -0.016134  0.005408 -2.983088  0.002854  **
# 17          t_2003    -0.009117  0.006665 -1.367967  0.171323
# 18          t_2004    -0.000204  0.014027 -0.014529  0.988408
# 19          t_2005    -0.007381  0.009911 -0.744770  0.456411
# 20          t_2006    -0.010708  0.009098 -1.176984  0.239202
# 21          t_2007    -0.010865  0.005286 -2.055603  0.039821   *
# 22          t_2008    -0.009389  0.007813 -1.201727  0.229469
# 23            _con     0.055122  0.091799  0.600466  0.548196
# AR(1) test P value:  9.12054566624908e-06
# AR(2) test P value:  0.6323169715342359
# Hansen test P value:  0.49586160042731453
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.051193  0.037398  1.368852  0.171045
# 1  L2.onset2COWCS    -0.019735  0.016563 -1.191487  0.233463
# 2              s1    -1.230471  1.388606 -0.886119  0.375553
# 3  trans_outp_p_x     0.004932  0.013835  0.356440  0.721511
# 4        ecgrowth    -0.123878  0.069126 -1.792071  0.073122
# 5        logpop_M     0.105031  0.081396  1.290383  0.196918
# 6      logpopdens    -0.013585  0.141717 -0.095860  0.923632
# 7       logoutreg     0.104750  0.431049  0.243011  0.807997
# AR(1) test P value:  2.380701379089231e-05
# AR(2) test P value:  0.9749282879110839
# Hansen test P value:  0.11405634416902422
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.048309  0.035406  1.364416  0.172437
# 1   L2.onset2COWCS    -0.017672  0.015971 -1.106563  0.268483
# 2               s1    -1.013298  0.940175 -1.077776  0.281134
# 3   trans_outp_p_x    -0.004603  0.013037 -0.353060  0.724044
# 4         ecgrowth    -0.121574  0.072949 -1.666562  0.095601
# 5         logpop_M     0.093282  0.067550  1.380926  0.167302
# 6       logpopdens     0.036532  0.111132  0.328725  0.742364
# 7        logoutreg     0.092600  0.330038  0.280575  0.779036
# 8           t_1994     0.078537  0.058096  1.351847  0.176424
# 9           t_1995     0.155957  0.124502  1.252643  0.210336
# 10          t_1996     0.215898  0.189410  1.139844  0.254351
# 11          t_1997     0.264751  0.268250  0.986956  0.323664
# 12          t_1998     0.398479  0.386325  1.031462  0.302324
# 13          t_1999     0.516059  0.498189  1.035870  0.300263
# 14          t_2000     0.680673  0.634213  1.073256  0.283156
# 15          t_2001     0.736251  0.721422  1.020556  0.307465
# 16          t_2002     0.895260  0.893852  1.001575  0.316549
# 17          t_2003     1.065898  1.032628  1.032219  0.301970
# 18          t_2004     1.222898  1.160920  1.053387  0.292164
# 19          t_2005     1.354560  1.286919  1.052561  0.292542
# 20          t_2006     1.458517  1.377275  1.058987  0.289605
# 21          t_2007     1.536857  1.438807  1.068147  0.285454
# 22          t_2008     1.585458  1.475887  1.074240  0.282715
# AR(1) test P value:  2.364646967958678e-05
# AR(2) test P value:  0.943117841440223
# Hansen test P value:  0.8092598287613328
