# %%
import pandas as pd
from pydynpd import regression
import pathlib
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %% [markdown]
# # Questions
# 1. perform one-step GMM estimation rather than the default two-step GMM estimation.
#
# # Assumption tests
# ## AR
# We expect to reject AR(1) but not AR(2)
# ## Overidentification
# A suggested rule of thumb is that any p-value between 0.1 and 0.25 should be fine as it is reasonably larger than a significance level of 0.05 and it is reasonably small enough to not suspect severe p-value inflation. In that case, system GMM without time dummy is the best result that we can get.

# %%
unstationary = 'ecgrowth logpop_M logpopdens logoutreg'
stationary = 'logmountain ethnic_fractionalization religion_fractionalization language_fractionalization leg_british opec'

path = pathlib.Path().resolve()
iv = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/transportIV_file.csv", na_values= '#DIV/0!')
# We do not introduce stationary controls under most circumstance. 
# Usually they do not change the results a lot, but that should be verified in the robustness check.
# No time FE if we are using world-level average gvc participation as external IV

# %%
def load_data(predictor = "gvcomix"):
    df = pd.read_csv(str(path).replace("code/Internal_IV", "data") + "/" + predictor + "_transformed1.csv", na_values= '#DIV/0!')
    df = pd.merge(df, iv, on=["country", "t"])
    label = le.fit_transform(df['country'])
    df.drop('country', axis=1, inplace=True)
    df['country'] = label
    df.fillna(0, inplace=True)
    return df

# %%
def reg(method=" ", additional_cntrl = False, time = False, iv = 'trans_outp_p_x'):
    # System GMM by default (method = "nolevel" produces difference GMM)
    # No stationary controls by default
    # IV = transport by default
    command_str = 'onset2COWCS L(1:?).onset2COWCS s10 ' + iv + ' ' + unstationary + ' '
    if additional_cntrl:
        command_str = command_str + stationary
    command_str = command_str + ' | gmm(onset2COWCS, 2:3) gmm(s10, 2:3) iv(' + iv + ') | ' + ' ' + method
    if time:
         command_str = command_str + ' timedumm'
    mydpd = regression.abond(command_str, df, ['country', 't']);
    return mydpd #.models[0] #.regression_table

# %%
def all_reg():
    # world average gvc participation IV.
    # Do not add time dummy
    ## System GMM
    m1 = reg(iv = 'avgs10');
    ## Difference GMM
    m2 = reg(iv = 'avgs10', method="nolevel");

    # Transport IV
    ## System GMM
    m3 = reg();
    m4 = reg(time = True);
    ## Difference GMM
    m5 = reg(method = "nolevel");
    m6 = reg(time = True, method="nolevel");

    results = [m1, m2, m3, m4, m5, m6]
    return results

# %%
def print_results(results):
    for idx in range(len(results)):
        if idx == 0:
            print("IV = World Average; Sys.")
        if idx == 1:
            print("IV = World Average; Dif.")
        if idx == 3:
            print("IV = Transport; Sys.")
        if idx == 4:
            print("IV = World Average; Sys; t-FE.")
        if idx == 5:
            print("IV = Transport; Dif.")
        if idx == 6:
            print("IV = World Average; Dif; t-FE.")
        m = results[idx].models[0]
        print(m.regression_table)
        print("AR(1) test P value: ", end=" ")
        print(m.AR_list[0].P_value)
        print("AR(2) test P value: ", end=" ")
        print(m.AR_list[1].P_value)
        print("Hansen test P value: ", end=" ")
        print(m.hansen.p_value)
        print("\n")

# %%
# %%capture
predictor_list = ["gvcomix", "gvcobp", "gvcofp"]
results_list = []
for predictor in predictor_list:
    df = load_data(predictor);
    results_list.append(all_reg());

# %%
for idx in range(len(results_list)):
    print("========Predictor = ", predictor_list[idx], "========")
    print_results(results_list[idx])
# Out:
# ========Predictor =  gvcomix ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.047330  0.035311  1.340371  0.180125
# 1              s6     0.301259  0.341425  0.882359  0.377583
# 2           avgs6    -0.840849  0.550114 -1.528500  0.126389
# 3        ecgrowth    -0.151795  0.063891 -2.375852  0.017508   *
# 4        logpop_M     0.113434  0.049493  2.291939  0.021909   *
# 5      logpopdens    -0.004777  0.105076 -0.045464  0.963738
# 6       logoutreg    -0.162757  0.215566 -0.755020  0.450237
# 7            _con     0.030417  0.037069  0.820539  0.411909
# AR(1) test P value:  2.1896020463913873e-05
# AR(2) test P value:  0.404836556221706
# Hansen test P value:  0.6599171845098645
#
#
# IV = World Average; Dif.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.058297  0.042373  1.375809  0.168881
# 1              s6     0.212817  0.329711  0.645467  0.518624
# 2           avgs6     0.044695  0.854674  0.052294  0.958294
# 3        ecgrowth    -0.175438  0.064834 -2.705950  0.006811  **
# 4        logpop_M     0.116062  0.059147  1.962267  0.049731   *
# 5      logpopdens     0.000714  0.105800  0.006752  0.994613
# 6       logoutreg     0.036853  0.747969  0.049271  0.960703
# AR(1) test P value:  2.1594703264524978e-05
# AR(2) test P value:  0.5417198746318848
# Hansen test P value:  0.1448280872769373
#
#
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.059870  0.041211  1.452750  0.146293
# 1  L2.onset2COWCS    -0.012171  0.006689 -1.819676  0.068808
# 2              s6     0.320235  0.353745  0.905272  0.365321
# 3  trans_outp_p_x     0.025533  0.019649  1.299462  0.193785
# 4        ecgrowth    -0.136103  0.110206 -1.234983  0.216837
# 5        logpop_M     0.149097  0.088941  1.676365  0.093667
# 6      logpopdens    -0.012801  0.117134 -0.109283  0.912978
# 7       logoutreg    -0.194083  0.275643 -0.704109  0.481365
# 8            _con     0.020283  0.046846  0.432971  0.665036
# AR(1) test P value:  8.345086434028088e-05
# AR(2) test P value:  0.7200060309903621
# Hansen test P value:  0.09101689963312865
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.044747  0.034700  1.289536  0.197212
# 1               s6     0.342962  0.374539  0.915689  0.359830
# 2   trans_outp_p_x     0.027465  0.026759  1.026396  0.304705
# 3         ecgrowth    -0.134506  0.065340 -2.058542  0.039538   *
# 4         logpop_M     0.123106  0.066634  1.847486  0.064677
# 5       logpopdens    -0.016009  0.092553 -0.172976  0.862670
# 6        logoutreg    -0.401126  0.407167 -0.985163  0.324544
# 7           t_1993    -0.017676  0.009986 -1.770122  0.076707
# 8           t_1994    -0.021088  0.014436 -1.460838  0.144060
# 9           t_1995    -0.024514  0.009935 -2.467400  0.013610   *
# 10          t_1996    -0.005917  0.011532 -0.513077  0.607898
# 11          t_1997    -0.019326  0.010102 -1.913044  0.055742
# 12          t_1998     0.007868  0.019922  0.394940  0.692887
# 13          t_1999    -0.015741  0.009528 -1.652093  0.098516
# 14          t_2000    -0.020935  0.010233 -2.045918  0.040764   *
# 15          t_2001    -0.024776  0.011445 -2.164816  0.030402   *
# 16          t_2002    -0.021650  0.008842 -2.448640  0.014340   *
# 17          t_2003    -0.021143  0.010210 -2.070796  0.038378   *
# 18          t_2004    -0.013236  0.016456 -0.804320  0.421212
# 19          t_2005    -0.012767  0.012454 -1.025161  0.305287
# 20          t_2006    -0.025825  0.011913 -2.167767  0.030176   *
# 21          t_2007    -0.020693  0.009817 -2.107803  0.035048   *
# 22          t_2008    -0.016114  0.010217 -1.577147  0.114762
# 23            _con     0.073113  0.074663  0.979232  0.327466
# AR(1) test P value:  3.664587112732573e-05
# AR(2) test P value:  0.37224266795097605
# Hansen test P value:  0.8814713499216013
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.058267  0.036894  1.579286  0.114270
# 1              s6     0.273217  0.413019  0.661511  0.508284
# 2  trans_outp_p_x     0.028692  0.036546  0.785088  0.432402
# 3        ecgrowth    -0.164213  0.066341 -2.475287  0.013313   *
# 4        logpop_M     0.146098  0.121198  1.205450  0.228030
# 5      logpopdens    -0.047473  0.155075 -0.306128  0.759507
# 6       logoutreg    -0.064059  0.452389 -0.141603  0.887394
# AR(1) test P value:  2.060998549858084e-05
# AR(2) test P value:  0.5352672416712412
# Hansen test P value:  0.24653065419710896
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.058069  0.035722  1.625613  0.104032
# 1               s6     0.281618  0.428522  0.657185  0.511062
# 2   trans_outp_p_x     0.026739  0.039329  0.679881  0.496580
# 3         ecgrowth    -0.166590  0.068344 -2.437514  0.014789   *
# 4         logpop_M     0.147197  0.136447  1.078789  0.280682
# 5       logpopdens    -0.042857  0.154670 -0.277089  0.781712
# 6        logoutreg    -0.066465  0.414997 -0.160157  0.872757
# 7           t_1993    -0.067767  0.634261 -0.106844  0.914913
# 8           t_1994    -0.159360  1.285214 -0.123995  0.901320
# 9           t_1995    -0.238866  1.943278 -0.122919  0.902171
# 10          t_1996    -0.337070  2.608833 -0.129203  0.897197
# 11          t_1997    -0.458212  3.342202 -0.137099  0.890953
# 12          t_1998    -0.567799  4.078705 -0.139211  0.889284
# 13          t_1999    -0.555550  4.381036 -0.126808  0.899092
# 14          t_2000    -0.409783  4.294426 -0.095422  0.923980
# 15          t_2001    -0.136573  3.834462 -0.035617  0.971587
# 16          t_2002     0.265361  3.134810  0.084650  0.932540
# 17          t_2003     0.560470  2.697351  0.207785  0.835397
# 18          t_2004     0.768778  2.404950  0.319665  0.749222
# 19          t_2005     0.865072  2.120999  0.407861  0.683376
# 20          t_2006     0.931680  1.983939  0.469611  0.638633
# 21          t_2007     0.991857  1.920484  0.516462  0.605532
# 22          t_2008     1.025194  1.898076  0.540123  0.589112
# AR(1) test P value:  2.1983116371195977e-05
# AR(2) test P value:  0.6227524977893033
# Hansen test P value:  0.3215855095142923
#
#
# ========Predictor =  gvcobp ========
# IV = World Average; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.060166  0.070260  0.856333  0.391813
# 1   L2.onset2COWCS     0.012193  0.014775  0.825232  0.409240
# 2   L3.onset2COWCS     0.006044  0.006814  0.887012  0.375073
# 3   L4.onset2COWCS    -0.016420  0.016837 -0.975185  0.329469
# 4   L5.onset2COWCS    -0.023321  0.037076 -0.629005  0.529346
# 5   L6.onset2COWCS    -0.033426  0.064831 -0.515578  0.606150
# 6   L7.onset2COWCS     0.026154  0.063049  0.414822  0.678272
# 7   L8.onset2COWCS    -0.012284  0.066712 -0.184138  0.853905
# 8               s6    -0.111884  0.156325 -0.715713  0.474169
# 9            avgs6    -0.864805  1.041009 -0.830738  0.406122
# 10        ecgrowth    -0.111551  0.120045 -0.929247  0.352761
# 11        logpop_M     0.088228  0.072516  1.216665  0.223732
# 12      logpopdens    -0.090734  0.089267 -1.016432  0.309424
# 13       logoutreg    -0.161090  0.202623 -0.795024  0.426600
# 14            _con     0.030434  0.035213  0.864278  0.387435
# AR(1) test P value:  0.0026225242884398287
# AR(2) test P value:  0.6558749262729229
# Hansen test P value:  0.996598363957685
#
#
# IV = World Average; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS    -0.428409  0.178265 -2.403219  0.016251   *
# 1   L2.onset2COWCS    -0.458944  0.192919 -2.378952  0.017362   *
# 2   L3.onset2COWCS    -0.489800  0.196463 -2.493090  0.012664   *
# 3   L4.onset2COWCS    -0.202485  0.204305 -0.991091  0.321641
# 4   L5.onset2COWCS    -0.091873  0.076961 -1.193774  0.232567
# 5               s6    -0.227148  0.131564 -1.726526  0.084253
# 6            avgs6     0.354240  1.863740  0.190069  0.849255
# 7         ecgrowth    -0.102887  0.065370 -1.573918  0.115506
# 8         logpop_M     0.041320  0.039032  1.058641  0.289763
# 9       logpopdens     0.011756  0.076872  0.152931  0.878453
# 10       logoutreg     0.107099  0.258628  0.414107  0.678796
# AR(1) test P value:  0.045039926156029544
# AR(2) test P value:  0.7859351304087627
# Hansen test P value:  0.1080015520276233
#
#
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.065586  0.079498  0.824998  0.409373
# 1   L2.onset2COWCS     0.009965  0.015537  0.641333  0.521306
# 2   L3.onset2COWCS     0.006330  0.009335  0.678120  0.497696
# 3   L4.onset2COWCS    -0.012595  0.016478 -0.764315  0.444679
# 4   L5.onset2COWCS    -0.024505  0.041443 -0.591295  0.554323
# 5   L6.onset2COWCS    -0.031352  0.072794 -0.430695  0.666690
# 6   L7.onset2COWCS     0.042603  0.105679  0.403137  0.686847
# 7   L8.onset2COWCS     0.002199  0.092793  0.023693  0.981097
# 8               s6    -0.091076  0.070509 -1.291686  0.196466
# 9   trans_outp_p_x     0.005741  0.011213  0.511959  0.608680
# 10        ecgrowth    -0.075768  0.127102 -0.596116  0.551098
# 11        logpop_M     0.095173  0.126090  0.754802  0.450368
# 12      logpopdens    -0.136111  0.136841 -0.994661  0.319901
# 13       logoutreg    -0.137164  0.234615 -0.584635  0.558793
# 14            _con     0.023054  0.043434  0.530781  0.595571
# AR(1) test P value:  0.003539853422987338
# AR(2) test P value:  0.7336777721199923
# Hansen test P value:  0.9722489997884901
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.058398  0.042000  1.390447  0.164393
# 1   L2.onset2COWCS    -0.018371  0.009699 -1.894085  0.058214
# 2               s6     0.024736  0.130658  0.189317  0.849845
# 3   trans_outp_p_x     0.010995  0.013714  0.801725  0.422712
# 4         ecgrowth    -0.146668  0.066743 -2.197505  0.027984   *
# 5         logpop_M     0.135592  0.059668  2.272429  0.023061   *
# 6       logpopdens    -0.066058  0.106385 -0.620935  0.534642
# 7        logoutreg    -0.374071  0.505320 -0.740267  0.459138
# 8           t_1994    -0.003036  0.008072 -0.376060  0.706872
# 9           t_1995    -0.014283  0.005564 -2.566839  0.010263   *
# 10          t_1996     0.003425  0.010722  0.319477  0.749364
# 11          t_1997    -0.013044  0.007397 -1.763370  0.077838
# 12          t_1998     0.012304  0.015443  0.796755  0.425593
# 13          t_1999    -0.008350  0.007604 -1.098107  0.272158
# 14          t_2000    -0.010442  0.009718 -1.074504  0.282597
# 15          t_2001    -0.013481  0.010428 -1.292765  0.196092
# 16          t_2002    -0.014523  0.005804 -2.501966  0.012351   *
# 17          t_2003    -0.011398  0.005783 -1.971117  0.048710   *
# 18          t_2004    -0.000803  0.006728 -0.119384  0.904971
# 19          t_2005    -0.002979  0.008847 -0.336756  0.736301
# 20          t_2006    -0.013283  0.007596 -1.748653  0.080351
# 21          t_2007    -0.010939  0.005143 -2.127073  0.033414   *
# 22          t_2008    -0.008289  0.005281 -1.569554  0.116519
# 23            _con     0.067611  0.088613  0.762990  0.445469
# AR(1) test P value:  2.6857799466326653e-05
# AR(2) test P value:  0.9582095678659625
# Hansen test P value:  0.4827790396229842
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value       p_value  sig
# 0  L1.onset2COWCS    -0.465293  0.096983 -4.797681  1.605128e-06  ***
# 1  L2.onset2COWCS    -0.505448  0.084430 -5.986620  2.142459e-09  ***
# 2  L3.onset2COWCS    -0.555191  0.096451 -5.756184  8.603665e-09  ***
# 3              s6    -0.246814  0.191820 -1.286698  1.981994e-01
# 4  trans_outp_p_x     0.007464  0.015331  0.486867  6.263527e-01
# 5        ecgrowth    -0.108347  0.060939 -1.777970  7.540877e-02
# 6        logpop_M     0.076509  0.058102  1.316813  1.879013e-01
# 7      logpopdens    -0.048031  0.115170 -0.417047  6.766443e-01
# 8       logoutreg     0.361281  0.390879  0.924277  3.553422e-01
# AR(1) test P value:  0.0010685587116120946
# AR(2) test P value:  0.8048175201629495
# Hansen test P value:  0.23669578817402925
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.065079  0.034933  1.862975  0.062466
# 1   L2.onset2COWCS    -0.017412  0.016459 -1.057907  0.290098
# 2               s6    -0.175727  0.233790 -0.751645  0.452264
# 3   trans_outp_p_x     0.005030  0.016533  0.304274  0.760919
# 4         ecgrowth    -0.161760  0.071826 -2.252110  0.024315   *
# 5         logpop_M     0.117999  0.065122  1.811975  0.069990
# 6       logpopdens    -0.041531  0.130531 -0.318169  0.750357
# 7        logoutreg     0.229264  0.683890  0.335235  0.737448
# 8           t_1994     0.128206  0.380727  0.336740  0.736313
# 9           t_1995     0.310141  0.939400  0.330148  0.741288
# 10          t_1996     0.497811  1.627409  0.305891  0.759687
# 11          t_1997     0.671233  2.429537  0.276280  0.782333
# 12          t_1998     0.855234  3.394766  0.251927  0.801097
# 13          t_1999     0.985848  4.023735  0.245008  0.806450
# 14          t_2000     1.071192  4.370380  0.245103  0.806377
# 15          t_2001     1.108115  4.388918  0.252480  0.800670
# 16          t_2002     1.083092  4.115685  0.263162  0.792426
# 17          t_2003     0.971346  3.536870  0.274634  0.783597
# 18          t_2004     0.772615  2.684301  0.287827  0.773479
# 19          t_2005     0.469589  1.767851  0.265627  0.790526
# 20          t_2006     0.252333  1.601519  0.157558  0.874805
# 21          t_2007     0.111408  1.824288  0.061069  0.951304
# 22          t_2008     0.048442  2.018839  0.023995  0.980857
# AR(1) test P value:  2.332593005222933e-05
# AR(2) test P value:  0.8178479852529477
# Hansen test P value:  0.517426739460352
#
#
# ========Predictor =  gvcofp ========
# IV = World Average; Sys.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.053336  0.037505  1.422113  0.154994
# 1              s6    -0.180692  0.247268 -0.730755  0.464929
# 2           avgs6     1.538484  0.632858  2.431011  0.015057   *
# 3        ecgrowth    -0.171696  0.052693 -3.258413  0.001120  **
# 4        logpop_M     0.123974  0.062282  1.990529  0.046533   *
# 5      logpopdens     0.023883  0.115522  0.206740  0.836213
# 6       logoutreg    -0.148711  0.260810 -0.570188  0.568550
# 7            _con     0.024825  0.045060  0.550938  0.581676
# AR(1) test P value:  7.919618323500487e-06
# AR(2) test P value:  0.5479180232145415
# Hansen test P value:  0.051199409853697087
#
#
# IV = World Average; Dif.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.059692  0.038070  1.567970  0.116888
# 1              s6    -0.026866  0.103110 -0.260562  0.794430
# 2           avgs6    -1.391013  1.198355 -1.160769  0.245736
# 3        ecgrowth    -0.174431  0.065584 -2.659655  0.007822  **
# 4        logpop_M     0.129271  0.077849  1.660522  0.096810
# 5      logpopdens    -0.020180  0.138619 -0.145575  0.884257
# 6       logoutreg     0.024194  0.496808  0.048699  0.961159
# AR(1) test P value:  7.701859215563227e-06
# AR(2) test P value:  0.6390883423118682
# Hansen test P value:  0.13321817713327067
#
#
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.064961  0.047740  1.360714  0.173604
# 1  L2.onset2COWCS    -0.011525  0.009248 -1.246274  0.212664
# 2  L3.onset2COWCS    -0.008600  0.005058 -1.700369  0.089062
# 3              s6    -0.127224  0.212058 -0.599949  0.548540
# 4  trans_outp_p_x     0.001986  0.012845  0.154636  0.877108
# 5        ecgrowth    -0.124750  0.060764 -2.053021  0.040071   *
# 6        logpop_M     0.086397  0.058633  1.473527  0.140609
# 7      logpopdens     0.027323  0.115570  0.236423  0.813104
# 8       logoutreg    -0.177160  0.220884 -0.802048  0.422525
# 9            _con     0.029829  0.040214  0.741744  0.458242
# AR(1) test P value:  5.870979927561483e-05
# AR(2) test P value:  0.7682693782994348
# Hansen test P value:  0.6537975308365767
#
#
# IV = Transport; Sys.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.045585  0.035809  1.273005  0.203016
# 1               s6    -0.170856  0.192102 -0.889405  0.373786
# 2   trans_outp_p_x     0.008899  0.011642  0.764374  0.444644
# 3         ecgrowth    -0.136185  0.052748 -2.581804  0.009829  **
# 4         logpop_M     0.102478  0.043666  2.346857  0.018933   *
# 5       logpopdens     0.001861  0.085199  0.021847  0.982570
# 6        logoutreg    -0.284792  0.370487 -0.768694  0.442075
# 7           t_1993    -0.017701  0.007055 -2.509171  0.012101   *
# 8           t_1994    -0.011511  0.006426 -1.791335  0.073239
# 9           t_1995    -0.018378  0.007209 -2.549407  0.010791   *
# 10          t_1996    -0.004650  0.009981 -0.465914  0.641277
# 11          t_1997    -0.018353  0.007893 -2.325327  0.020054   *
# 12          t_1998     0.003671  0.014140  0.259631  0.795148
# 13          t_1999    -0.014586  0.006622 -2.202581  0.027624   *
# 14          t_2000    -0.016091  0.010142 -1.586514  0.112623
# 15          t_2001    -0.019585  0.008690 -2.253649  0.024218   *
# 16          t_2002    -0.019813  0.007262 -2.728407  0.006364  **
# 17          t_2003    -0.017398  0.008064 -2.157532  0.030964   *
# 18          t_2004    -0.003626  0.010726 -0.338102  0.735286
# 19          t_2005    -0.011210  0.007490 -1.496653  0.134484
# 20          t_2006    -0.017999  0.008358 -2.153651  0.031268   *
# 21          t_2007    -0.016645  0.006911 -2.408487  0.016019   *
# 22          t_2008    -0.014658  0.006284 -2.332702  0.019664   *
# 23            _con     0.058492  0.065731  0.889874  0.373533
# AR(1) test P value:  8.03814235054613e-06
# AR(2) test P value:  0.4647791275557419
# Hansen test P value:  0.9985368582493261
#
#
# IV = World Average; Sys; t-FE.
#          variable  coefficient   std_err   z_value   p_value sig
# 0  L1.onset2COWCS     0.060816  0.033876  1.795250  0.072614
# 1              s6    -0.028057  0.087506 -0.320628  0.748492
# 2  trans_outp_p_x     0.009087  0.010916  0.832471  0.405143
# 3        ecgrowth    -0.185912  0.064959 -2.862008  0.004210  **
# 4        logpop_M     0.139096  0.058352  2.383753  0.017137   *
# 5      logpopdens    -0.015723  0.140292 -0.112073  0.910766
# 6       logoutreg     0.108060  0.491252  0.219968  0.825896
# AR(1) test P value:  5.92608133722192e-06
# AR(2) test P value:  0.6448281971433673
# Hansen test P value:  0.07547380779156998
#
#
# IV = Transport; Dif.
#           variable  coefficient   std_err   z_value   p_value sig
# 0   L1.onset2COWCS     0.060356  0.035475  1.701365  0.088874
# 1               s6    -0.017713  0.059824 -0.296088  0.767163
# 2   trans_outp_p_x     0.009204  0.012253  0.751210  0.452526
# 3         ecgrowth    -0.185516  0.064988 -2.854638  0.004309  **
# 4         logpop_M     0.154972  0.063952  2.423244  0.015383   *
# 5       logpopdens    -0.036865  0.141743 -0.260080  0.794802
# 6        logoutreg    -0.014636  0.515113 -0.028414  0.977332
# 7           t_1993    -0.115507  0.159484 -0.724256  0.468908
# 8           t_1994    -0.249444  0.315475 -0.790695  0.429122
# 9           t_1995    -0.362548  0.770920 -0.470280  0.638155
# 10          t_1996    -0.496692  1.166457 -0.425813  0.670244
# 11          t_1997    -0.647891  1.336843 -0.484643  0.627930
# 12          t_1998    -0.785117  1.652986 -0.474969  0.634809
# 13          t_1999    -0.989041  1.857210 -0.532542  0.594351
# 14          t_2000    -1.250785  2.023145 -0.618238  0.536418
# 15          t_2001    -1.572769  2.126454 -0.739620  0.459531
# 16          t_2002    -1.963737  2.331917 -0.842113  0.399725
# 17          t_2003    -1.883318  2.244873 -0.838942  0.401502
# 18          t_2004    -1.329269  1.842997 -0.721254  0.470753
# 19          t_2005    -0.322385  1.193400 -0.270140  0.787053
# 20          t_2006     0.436436  1.211131  0.360354  0.718582
# 21          t_2007     0.952293  1.399663  0.680373  0.496268
# 22          t_2008     1.221622  1.542348  0.792053  0.428330
# AR(1) test P value:  8.476287716265282e-06
# AR(2) test P value:  0.7861221154834064
# Hansen test P value:  0.20284136546401887
